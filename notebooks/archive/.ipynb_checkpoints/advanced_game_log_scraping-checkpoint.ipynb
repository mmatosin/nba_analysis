# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# #### data directories

# %%
currDir = os.getcwd()
rootDir = os.path.abspath(os.path.join(currDir,'..'))

dataDir = os.path.abspath(os.path.join(rootDir,'data'))
rawDataDir = os.path.abspath(os.path.join(dataDir,'raw'))
interimDataDir = os.path.abspath(os.path.join(dataDir,'interim'))
finalDataDir = os.path.abspath(os.path.join(dataDir,'final'))

advDataDir = os.path.abspath(os.path.join(dataDir,'advanced_stats'))
errorLog = os.path.abspath(os.path.join(dataDir,'error_log'))

# %% [markdown]
# #### read player bio data

# %%
file = f"{rawDataDir}/all_NBA_ABA_players.csv"
df = pd.read_csv(file)

print("No of distinct players:",df['index'].nunique())
# Out:
# No of distinct players: 4800

# %%
df.head()
# Out:
#        index                Player  From    To  Pos    Ht     Wt  \
# 0  abdelal01        Alaa Abdelnaby  1991  1995  F-C  6-10  240.0
# 1  abdulza01       Zaid Abdul-Aziz  1969  1978  C-F   6-9  235.0
# 2  abdulka01  Kareem Abdul-Jabbar*  1970  1989    C   7-2  225.0
# 3  abdulma02    Mahmoud Abdul-Rauf  1991  2001    G   6-1  162.0
# 4  abdulta01     Tariq Abdul-Wahad  1998  2003    F   6-6  223.0
#
#          Birth Date                  Colleges
# 0     June 24, 1968                      Duke
# 1     April 7, 1946                Iowa State
# 2    April 16, 1947                      UCLA
# 3     March 9, 1969                       LSU
# 4  November 3, 1974  Michigan, San Jose State

# %% [markdown]
# #### scraping player game logs

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

#### BASIC STATS
# https://www.basketball-reference.com/players/a/abdelal01.html
# https://www.basketball-reference.com/players/a/abdelal01/gamelog/1992
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-playoffs/

#### ADVANCED STATS
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-advanced/1992/
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-playoffs-advanced/

# %%
def get_reg_season_game_logs(player_idx,letter,from_year,to_year):
    reg_season_game_logs = None
    yearly_dfs = []
    
    # SCRAPING REGULAR SEASON GAMES
    
    for year in range(from_year, to_year+1):
        #url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog/{year}"
        url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-advanced/{year}/"
        webpage = urlopen(url)
        html = BeautifulSoup(webpage)
        tables = html.findAll('table')
      
        if len(tables)==0:
            if year > 1976: continue
            else:
                aba_url = url + "/aba/"
                webpage = urlopen(aba_url)
                html = BeautifulSoup(webpage)
                aba_tables = html.findAll('table')

                if len(aba_tables)==0: continue
                else: 
                    table = str(aba_tables[-1])
                    yearly_game_log = pd.read_html(table)[0]
                    yearly_game_log["PLAYOFF"] = 'N'
                    yearly_game_log["LEAGUE"] = 'ABA'

        else:
            table = str(tables[-1])
            yearly_game_log = pd.read_html(table)[0]
            yearly_game_log["PLAYOFF"] = 'N'
            yearly_game_log["LEAGUE"] = 'NBA'

        yearly_dfs.append(yearly_game_log)        

    reg_season_game_logs = pd.concat([x for x in yearly_dfs],ignore_index=True,sort=False)
    reg_season_game_logs["PLAYOFF"] = 'N'
    reg_season_game_logs['SERIES'] = np.nan

    reg_season_game_logs.rename(columns = {'Date': 'DATE', 'Age': 'AGE', 'Tm': 'TEAM', 
                                      'Unnamed: 5': 'HOME/AWAY', 'Opp': 'OPPONENT',
                                      'Unnamed: 7': 'RESULT', 'GmSc': 'GAME_SCORE'}, inplace=True)  
    
    return reg_season_game_logs

# %%
def get_playoff_game_logs(player_idx,letter):
    
    playoff_game_logs = None
    
    #playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs/"
    playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs-advanced/"
    webpage = urlopen(playoff_url)
    html = BeautifulSoup(webpage)
    tables = html.findAll('table')
    
    if len(tables) > 0:
        table = str(html.findAll('table')[-1])
        playoff_game_logs = pd.read_html(table)[0]
        playoff_game_logs["PLAYOFF"] = 'Y'
        playoff_game_logs["AGE"] = np.nan

        playoff_game_logs.rename(columns = {'Date': 'DATE', 'Age': 'AGE', 'Tm': 'TEAM', 'Series':'SERIES',
                                          'Unnamed: 5': 'HOME/AWAY', 'Opp': 'OPPONENT',playoff_game_logs.columns[2]:'DATE',
                                          'Unnamed: 8': 'RESULT', 'GmSc': 'GAME_SCORE'}, inplace=True)
    
    return playoff_game_logs

# %%
def get_career_game_logs(player_data,verbose=True):
    
    logger = f"{errorLog}/log.txt"
    
    # PLAYER DATA
    player_idx = player_data['index']
    letter = player_idx[0]
    player_name = player_data['Player']
    from_yr, to_yr = row[["From","To"]].values

    if verbose:
        print(player_idx,player_name)
    
    # GET REGULAR SEASON GAME LOGS
    try:
        reg_season_game_logs = get_reg_season_game_logs(player_idx,letter,from_yr,to_yr)
    except:
        reg_season_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, error in regular season game logs \n")

    # GET PLAYOFF GAME LOGS
    try:
        playoff_game_logs = get_playoff_game_logs(player_idx,letter)
    except:
        playoff_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, error in playoff game logs \n")
            
        
    try:  
        # CONCATENATING REGULAR SEASON AND PLAYOFF GAMES
        career_game_logs = pd.concat([reg_season_game_logs,playoff_game_logs],ignore_index=True,sort=False)
        career_game_logs['HOME/AWAY'] = career_game_logs['HOME/AWAY'].apply(lambda x: 'AWAY' if x=='@' else 'HOME')

        # FORMAT CAREER GAME LOGS, SORT BY DATE
        career_game_logs['Rk'] = career_game_logs['Rk'].astype(str)
        career_game_logs = career_game_logs[career_game_logs['Rk'].str.isnumeric().values]

        career_game_logs.rename(columns = {'Series':'SERIES'},inplace=True)
        career_game_logs['INDEX'] = player_idx
        career_game_logs['NAME']  = player_name

        career_game_logs.sort_values('DATE',inplace=True)
        career_game_logs.reset_index(drop=True,inplace=True)

    except:
        career_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, no playoff OR regular season data \n")
        
    return career_game_logs

# %%
k, w = 3000, 4000
player_dfs = []
for num,(index, row) in enumerate(df.iloc[k:w].iterrows()):
    print(k + num)
    
    if (num + 1) % 10 == 0:
        game_logs = pd.concat([player for player in player_dfs],ignore_index=True,sort=False)
        game_logs.to_csv(f"{advDataDir}/adv_game_logs.csv",index=False)
        print("df shape",game_logs.shape)
    
    career_game_logs = get_career_game_logs(row)
    player_dfs.append(career_game_logs)
    
    try:
        print(career_game_logs.shape)
    except:
        print("both dfs are None")
    
game_logs = pd.concat([player for player in player_dfs],ignore_index=True,sort=False)
print("\n")
print(game_logs.shape)

game_logs.to_csv(f"{advDataDir}/adv_game_logs - extract {k}-{w-1}.csv"
                 ,index=False)
# Out:
# 3000
# morrima01 Max Morris
# (65, 23)
# 3001
# morrimo01 Monte Morris
# (229, 30)
# 3002
# morrira01 Randolph Morris
# (266, 30)
# 3003
# morrite01 Terence Morris
# (206, 29)
# 3004
# morriad01 Adam Morrison
# (330, 30)
# 3005
# morrijo01 John Morrison
# (8, 25)
# 3006
# morrimi01 Mike Morrison
# (36, 29)
# 3007
# morrire01 Red Morrison
# (165, 23)
# 3008
# morroan01 Anthony Morrow
# (745, 31)
# 3009
# df shape (2050, 31)
# mortodw01 Dwayne Morton
# (41, 29)
# 3010
# mortojo01 John Morton
# (131, 30)
# 3011
# mortori01 Richard Morton
# (2, 29)
# 3012
# moslegl01 Glenn Mosley
# (32, 28)
# 3013
# mosspe01 Perry Moss
# (151, 30)
# 3014
# motenla01 Lawrence Moten
# (135, 29)
# 3015
# motiedo01 Donatas Motiejūnas
# (420, 31)
# 3016
# motlejo01 Johnathan Motley
# (228, 29)
# 3017
# mottoha01 Hanno Möttölä
# (160, 29)
# 3018
# moultar01 Arnett Moultrie
# (164, 29)
# 3019
# df shape (3514, 31)
# mountri01 Rick Mount
# (347, 28)
# 3020
# mournal01 Alonzo Mourning*
# (1048, 30)
# 3021
# mozgoti01 Timofey Mozgov
# (696, 31)
# 3022
# mrazoch01 Chuck Mrazovich
# (23, 22)
# 3023
# mudiaem01 Emmanuel Mudiay
# (390, 29)
# 3024
# mueller01 Erwin Mueller
# (449, 28)
# 3025
# muhamsh01 Shabazz Muhammad
# (419, 31)
# 3026
# muldemy01 Mychal Mulder
# (7, 29)
# 3027
# mullajo01 Joe Mullaney
# (31, 22)
# 3028
# mullebo01 Bob Mullens
# (52, 22)
# 3029
# df shape (6976, 31)
# mulleby01 Byron Mullens
# (396, 30)
# 3030
# mullich01 Chris Mullin*
# (1102, 30)
# 3031
# mullije01 Jeff Mullins
# (883, 25)
# 3032
# mundtto01 Todd Mundt
# (33, 29)
# 3033
# munfoxa02 Xavier Munford
# (63, 30)
# 3034
# munkch01 Chris Munk
# (11, 29)
# 3035
# munroge01 George Munroe
# (87, 23)
# 3036
# murdoer01 Eric Murdock
# (535, 30)
# 3037
# muresgh01 Gheorghe Mureșan
# (348, 30)
# 3038
# murphal01 Allen Murphy
# (31, 27)
# 3039
# df shape (10465, 31)
# murphca01 Calvin Murphy*
# (1053, 29)
# 3040
# murphdi01 Dick Murphy
# (19, 22)
# 3041
# murpher01 Erik Murphy
# (81, 29)
# 3042
# murphja01 Jay Murphy
# (67, 29)
# 3043
# murphjo01 John Murphy
# (18, 22)
# 3044
# murphke01 Kevin Murphy
# (82, 29)
# 3045
# murphro01 Ronnie Murphy
# (18, 29)
# 3046
# murphto01 Tod Murphy
# (191, 29)
# 3047
# murphtr01 Troy Murphy
# (862, 30)
# 3048
# murrade01 Dejounte Murray
# (337, 31)
# 3049
# df shape (13193, 31)
# murraja01 Jamal Murray
# (311, 30)
# 3050
# murrake01 Ken Murray
# (179, 23)
# 3051
# murrala01 Lamond Murray
# (860, 30)
# 3052
# murraro01 Ronald Murray
# (638, 30)
# 3053
# murratr01 Tracy Murray
# (758, 30)
# 3054
# murrewi01 Willie Murrell
# (249, 26)
# 3055
# murredo01 Dorie Murrey
# (371, 23)
# 3056
# murryto01 Toure' Murry
# (124, 29)
# 3057
# musadz01 Džanan Musa
# (151, 31)
# 3058
# muscami01 Mike Muscala
# (537, 31)
# 3059
# df shape (17371, 31)
# musian01 Angelo Musi
# (186, 23)
# 3060
# mustaje01 Jerrod Mustaf
# (189, 30)
# 3061
# mutomdi01 Dikembe Mutombo*
# (1436, 30)
# 3062
# muursma01 Martin Müürsepp
# (131, 29)
# 3063
# myerspe01 Pete Myers
# (424, 30)
# 3064
# mykhasv01 Sviatoslav Mykhailiuk
# (149, 29)
# 3065
# ndiayha01 Hamady N'Diaye
# (139, 29)
# 3066
# ndiayma01 Makhtar N'Diaye
# (4, 29)
# 3067
# ndiayma02 Mamadou N'Diaye
# (176, 29)
# 3068
# ndongbo01 Boniface N'Dong
# (81, 29)
# 3069
# df shape (20286, 31)
# naberbo01 Bob Naber
# (4, 22)
# 3070
# nachabo01 Boris Nachamkin
# (6, 22)
# 3071
# nachbbo01 Boštjan Nachbar
# (483, 30)
# 3072
# naderab01 Abdel Nader
# (252, 31)
# 3073
# nagelje01 Jerry Nagel
# (13, 22)
# 3074
# nagyfr01 Fritz Nagy
# (50, 22)
# 3075
# nailole01 Lee Nailon
# (423, 30)
# 3076
# najered01 Eduardo Nájera
# (936, 30)
# 3077
# nancela01 Larry Nance
# (988, 30)
# 3078
# nancela02 Larry Nance
# (393, 31)
# 3079
# df shape (23834, 31)
# napiesh01 Shabazz Napier
# (488, 31)
# 3080
# napolpa01 Paul Napolitano
# both dfs are None
# 3081
# nashbo01 Bob Nash
# (241, 29)
# 3082
# nashco01 Cotton Nash
# (83, 25)
# 3083
# nashst01 Steve Nash*
# (1549, 31)
# 3084
# natersw01 Swen Nater
# (751, 29)
# 3085
# nathaho01 Howard Nathan
# (5, 29)
# 3086
# nattca01 Calvin Natt
# (644, 30)
# 3087
# nattke01 Kenny Natt
# (49, 29)
# 3088
# naullwi01 Willie Naulls
# (752, 23)
# 3089
# df shape (28396, 31)
# navarju01 Juan Carlos Navarro
# (82, 29)
# 3090
# ndourma01 Maurice Ndour
# (82, 29)
# 3091
# nealcr01 Craig Neal
# (63, 29)
# 3092
# nealga01 Gary Neal
# (505, 30)
# 3093
# nealji01 Jim Neal
# (66, 23)
# 3094
# nealll01 Lloyd Neal
# (457, 28)
# 3095
# nealyed01 Ed Nealy
# (573, 30)
# 3096
# nedovne01 Nemanja Nedović
# (89, 31)
# 3097
# negraal01 Al Negratti
# (11, 22)
# 3098
# nelsoba01 Barry Nelson
# (26, 23)
# 3099
# df shape (30350, 31)
# nelsode01 DeMarcus Nelson
# (39, 29)
# 3100
# nelsodo01 Don Nelson*
# (1201, 25)
# 3101
# nelsoja01 Jameer Nelson
# (1176, 30)
# 3102
# nelsolo01 Louie Nelson
# (223, 27)
# 3103
# nelsoro01 Ron Nelson
# (55, 26)
# 3104
# nembhru01 Ruben Nembhard
# (17, 29)
# 3105
# nemeldi01 Dick Nemelka
# (37, 26)
# 3106
# nesbyty01 Tyrone Nesby
# (276, 29)
# 3107
# nesslma01 Martin Nessley
# (44, 29)
# 3108
# nestera01 Rasho Nesterović
# (957, 30)
# 3109
# df shape (34375, 31)
# netora01 Raul Neto
# (420, 31)
# 3110
# netolbo01 Bob Netolicky
# (690, 28)
# 3111
# neumajo01 Johnny Neumann
# (485, 29)
# 3112
# neumapa01 Paul Neumann
# (480, 23)
# 3113
# nevitch01 Chuck Nevitt
# (171, 30)
# 3114
# newbeme01 Melvin Newbern
# (33, 29)
# 3115
# newbiiv01 Ivano Newbill
# (196, 30)
# 3116
# newblir01 Ira Newble
# (555, 30)
# 3117
# newlimi01 Mike Newlin
# (859, 29)
# 3118
# newmajo01 Johnny Newman
# (1216, 30)
# 3119
# df shape (39480, 31)
# newmama01 Malik Newman
# (3, 29)
# 3120
# newmada01 Dave Newmark
# (175, 26)
# 3121
# newtobi01 Bill Newton
# (34, 28)
# 3122
# niangge01 Georges Niang
# (277, 31)
# 3123
# nichode01 Demetris Nichols
# (106, 29)
# 3124
# nichoja01 Jack Nichols
# (557, 23)
# 3125
# nichoan01 Andrew Nicholson
# (409, 29)
# 3126
# nickega01 Gaylon Nickerson
# (14, 29)
# 3127
# nicksca01 Carl Nicks
# (156, 28)
# 3128
# niemari01 Rich Niemann
# (127, 27)
# 3129
# df shape (41338, 31)
# niemiri01 Richie Niemiera
# (112, 23)
# 3130
# nilesmi01 Mike Niles
# (46, 29)
# 3131
# nimphku01 Kurt Nimphius
# (589, 30)
# 3132
# nixdy01 Dyron Nix
# (20, 29)
# 3133
# nixonno01 Norm Nixon
# (826, 30)
# 3134
# noahjo01 Joakim Noah
# (1006, 30)
# 3135
# noblech01 Chuck Noble
# (441, 23)
# 3136
# nocioan01 Andrés Nocioni
# (640, 30)
# 3137
# noelda01 David Noel
# (82, 29)
# 3138
# noelne01 Nerlens Noel
# (479, 30)
# 3139
# df shape (45579, 31)
# noelpa01 Paul Noel
# (207, 23)
# 3140
# noguelu01 Lucas Nogueira
# (372, 31)
# 3141
# nolanji01 Jim Nolan
# (4, 22)
# 3142
# nolenpa01 Paul Nolen
# (1, 22)
# 3143
# nordgje01 Jeff Nordgaard
# (27, 29)
# 3144
# nordmbe01 Bevo Nordmann
# (131, 23)
# 3145
# norlajo01 Johnny Norlander
# (234, 23)
# 3146
# normaco01 Connie Norman
# (100, 28)
# 3147
# normake01 Ken Norman
# (688, 30)
# 3148
# norriau01 Audie Norris
# (207, 30)
# 3149
# df shape (47550, 31)
# norrimo01 Moochie Norris
# (510, 30)
# 3150
# norrisy01 Sylvester Norris
# (17, 28)
# 3151
# norveza01 Zach Norvell
# (28, 29)
# 3152
# norwowi01 Willie Norwood
# (443, 28)
# 3153
# nostrge01 George Nostrand
# (223, 23)
# 3154
# noszkst01 Stan Noszka
# (111, 23)
# 3155
# novakmi01 Mike Novak
# (118, 23)
# 3156
# novakst01 Steve Novak
# (861, 31)
# 3157
# nowelja01 Jaylen Nowell
# (64, 29)
# 3158
# nowelme01 Mel Nowell
# (114, 25)
# 3159
# df shape (50039, 31)
# nowitdi01 Dirk Nowitzki
# (1817, 30)
# 3160
# ntilila01 Frank Ntilikina
# (230, 29)
# 3161
# nunnke01 Kendrick Nunn
# (65, 29)
# 3162
# nunnaja01 James Nunnally
# (61, 29)
# 3163
# nurkiju01 Jusuf Nurkić
# (434, 31)
# 3164
# nuttde01 Dennis Nutt
# (26, 30)
# 3165
# nwabada01 David Nwaba
# (219, 29)
# 3166
# nwosuju01 Julius Nwosu
# (23, 30)
# 3167
# obannch01 Charles O'Bannon
# (99, 30)
# 3168
# obanned01 Ed O'Bannon
# (149, 29)
# 3169
# df shape (53162, 31)
# oboyljo01 John O'Boyle
# (5, 22)
# 3170
# obriebo01 Bob O'Brien
# (43, 23)
# 3171
# obriejj01 J.J. O'Brien
# (5, 29)
# 3172
# obrieji02 Jim O'Brien
# (64, 28)
# 3173
# obrieji01 Jimmy O'Brien
# (333, 28)
# 3174
# obriera01 Ralph O'Brien
# (122, 23)
# 3175
# obryajo01 Johnny O'Bryant
# (259, 31)
# 3176
# obryapa01 Patrick O'Bryant
# (327, 29)
# 3177
# oconnde01 Dermie O'Connell
# (81, 22)
# 3178
# odonnan01 Andy O'Donnell
# (24, 22)
# 3179
# df shape (54425, 31)
# ogradbu01 Buddy O'Grady
# (158, 23)
# 3180
# ohanlfr01 Fran O'Hanlon
# (11, 25)
# 3181
# okeefdi01 Dick O'Keefe
# (184, 23)
# 3182
# okeefto01 Tommy O'Keefe
# (5, 22)
# 3183
# okoremi01 Mike O'Koren
# (427, 30)
# 3184
# omallgr01 Grady O'Malley
# (23, 22)
# 3185
# onealje01 Jermaine O'Neal
# (1459, 30)
# 3186
# onealsh01 Shaquille O'Neal*
# (1657, 30)
# 3187
# onealro01 Royce O'Neale
# (244, 30)
# 3188
# oneilmi01 Mike O'Neill
# (4, 22)
# 3189
# df shape (58597, 31)
# oquinky01 Kyle O'Quinn
# (643, 31)
# 3190
# osheake01 Kevin O'Shea
# (166, 23)
# 3191
# oshiega01 Garland O'Shields
# (7, 22)
# 3192
# osullda01 Dan O'Sullivan
# (45, 29)
# 3193
# oaklech01 Charles Oakley
# (1503, 30)
# 3194
# obertfa01 Fabricio Oberto
# (461, 30)
# 3195
# ochefda01 Daniel Ochefu
# (82, 31)
# 3196
# odengr01 Greg Oden
# (397, 31)
# 3197
# odomla01 Lamar Odom
# (1155, 30)
# 3198
# ogdenbu01 Bud Ogden
# (74, 23)
# 3199
# df shape (63130, 31)
# ogdenra01 Ralph Ogden
# (32, 23)
# 3200
# oggal01 Alan Ogg
# (83, 30)
# 3201
# ohldo01 Don Ohl
# (773, 23)
# 3202
# ohlbrti01 Tim Ohlbrecht
# (20, 29)
# 3203
# ojelese01 Semi Ojeleye
# (256, 31)
# 3204
# okafoem01 Emeka Okafor
# (844, 31)
# 3205
# okafoja01 Jahlil Okafor
# (392, 29)
# 3206
# okoboel01 Elie Okobo
# (147, 29)
# 3207
# okogijo01 Josh Okogie
# (146, 29)
# 3208
# okpalkz01 KZ Okpala
# (65, 29)
# 3209
# df shape (65888, 31)
# okurme01 Mehmet Okur
# (849, 30)
# 3210
# oladivi01 Victor Oladipo
# (573, 31)
# 3211
# olajuha01 Hakeem Olajuwon*
# (1409, 30)
# 3212
# olberma01 Mark Olberding
# (1000, 30)
# 3213
# oldhaja01 Jawann Oldham
# (334, 30)
# 3214
# oldhajo01 John Oldham
# (132, 23)
# 3215
# oleynfr01 Frank Oleynick
# (102, 24)
# 3216
# olivejo01 John Olive
# (35, 28)
# 3217
# olivebr01 Brian Oliver
# (120, 30)
# 3218
# olivede01 Dean Oliver
# (60, 29)
# 3219
# df shape (70502, 31)
# oliveji01 Jimmy Oliver
# (81, 29)
# 3220
# ollieke01 Kevin Ollie
# (933, 30)
# 3221
# ollrige01 Gene Ollrich
# (14, 22)
# 3222
# olowomi01 Michael Olowokandi
# (629, 30)
# 3223
# olsenbu01 Bud Olsen
# (474, 26)
# 3224
# olynyke01 Kelly Olynyk
# (590, 31)
# 3225
# onimi01 Miye Oni
# (64, 29)
# 3226
# onuakar01 Arinze Onuaku
# (59, 29)
# 3227
# onuakch01 Chinanu Onuaku
# (192, 31)
# 3228
# ormsba01 Barry Orms
# (143, 26)
# 3229
# df shape (73681, 31)
# orrjo01 Johnny Orr
# (31, 22)
# 3230
# orrlo01 Louis Orr
# (591, 30)
# 3231
# ortizjo01 José Ortiz
# (64, 29)
# 3232
# ortonda01 Daniel Orton
# (197, 31)
# 3233
# osborch01 Chuck Osborne
# (4, 22)
# 3234
# osmande01 Cedi Osman
# (229, 31)
# 3235
# osterwa01 Wally Osterkorn
# (237, 23)
# 3236
# ostergr01 Greg Ostertag
# (918, 30)
# 3237
# othicma01 Matt Othick
# (4, 29)
# 3238
# ottendo01 Don Otten
# (223, 23)
# 3239
# df shape (76179, 31)
# ottenma01 Mac Otten
# (52, 22)
# 3240
# oubreke01 Kelly Oubre
# (412, 31)
# 3241
# outlabo01 Bo Outlaw
# (1087, 30)
# 3242
# outlatr01 Travis Outlaw
# (840, 30)
# 3243
# overtcl01 Claude Overton
# (15, 22)
# 3244
# overtdo01 Doug Overton
# (574, 29)
# 3245
# owensan01 Andre Owens
# (163, 29)
# 3246
# owensbi01 Billy Owens
# (667, 30)
# 3247
# owensch01 Chris Owens
# (5, 29)
# 3248
# owensed01 Eddie Owens
# (8, 27)
# 3249
# df shape (80002, 31)
# owensji01 Jim Owens
# (58, 24)
# 3250
# owenske01 Keith Owens
# (20, 29)
# 3251
# owensla01 Larry Owens
# (23, 29)
# 3252
# owensre01 Red Owens
# (84, 23)
# 3253
# owensta01 Tariq Owens
# (25, 29)
# 3254
# owensto01 Tom Owens
# (920, 29)
# 3255
# owesra01 Ray Owes
# (82, 29)
# 3256
# oyedeol01 Olumide Oyedeji
# (202, 30)
# 3257
# pacejo01 Joe Pace
# (79, 28)
# 3258
# pachuza01 Zaza Pachulia
# (1395, 31)
# 3259
# df shape (82890, 31)
# packro01 Robert Pack
# (682, 30)
# 3260
# packwa01 Wayne Pack
# (21, 27)
# 3261
# paddige01 Gerald Paddio
# (129, 30)
# 3262
# padgesc01 Scott Padgett
# (632, 30)
# 3263
# pagetda01 Dana Pagett
# (5, 26)
# 3264
# paigema01 Marcus Paige
# (82, 29)
# 3265
# painefr01 Fred Paine
# (3, 22)
# 3266
# palacmi01 Milt Palacio
# (536, 29)
# 3267
# palazto01 Togo Palazzi
# (347, 23)
# 3268
# palmebu01 Bud Palmer
# (162, 23)
# 3269
# df shape (85489, 31)
# palmeer01 Errol Palmer
# (65, 26)
# 3270
# palmeji01 Jim Palmer
# (197, 22)
# 3271
# palmewa01 Walter Palmer
# (48, 30)
# 3272
# pankoan01 Andy Panko
# (3, 29)
# 3273
# papagge01 Georgios Papagiannis
# (152, 29)
# 3274
# papanko01 Kostas Papanikolaou
# (114, 31)
# 3275
# pargoja01 Jannero Pargo
# (757, 31)
# 3276
# pargoje01 Jeremy Pargo
# (136, 29)
# 3277
# parhaea01 Easy Parham
# (129, 23)
# 3278
# parisro01 Robert Parish*
# (1816, 30)
# 3279
# df shape (88906, 31)
# parkme01 Med Park
# (339, 23)
# 3280
# parkean01 Anthony Parker
# (576, 30)
# 3281
# parkeja01 Jabari Parker
# (495, 31)
# 3282
# parkesm01 Smush Parker
# (355, 30)
# 3283
# parkeso01 Sonny Parker
# (452, 29)
# 3284
# parketo01 Tony Parker
# (1689, 31)
# 3285
# parkhba01 Barry Parkhill
# (176, 28)
# 3286
# parkija01 Jack Parkinson
# (2, 22)
# 3287
# parksch01 Charles Parks
# (1, 25)
# 3288
# parksch02 Cherokee Parks
# (579, 30)
# 3289
# df shape (93570, 31)
# parksri01 Richard Parks
# (42, 26)
# 3290
# parrja01 Jack Parr
# (65, 22)
# 3291
# parrado01 Doyle Parrack
# (57, 23)
# 3292
# parslch01 Charlie Parsley
# (8, 22)
# 3293
# parsoch01 Chandler Parsons
# (720, 31)
# 3294
# pascher01 Eric Paschall
# (65, 29)
# 3295
# pasecan01 Anžejs Pasečņiks
# (39, 29)
# 3296
# paspaza01 Žarko Paspalj
# (28, 29)
# 3297
# passama01 Marty Passaglia
# (65, 23)
# 3298
# pastuge01 George Pastushok
# (39, 22)
# 3299
# df shape (94698, 31)
# patrimy01 Myles Patrick
# (3, 28)
# 3300
# patrist01 Stan Patrick
# (55, 23)
# 3301
# pattean01 Andrae Patterson
# (63, 30)
# 3302
# pattege01 George Patterson
# (60, 23)
# 3303
# pattela01 Lamar Patterson
# (93, 31)
# 3304
# pattepa01 Patrick Patterson
# (838, 31)
# 3305
# patteru01 Ruben Patterson
# (720, 30)
# 3306
# pattest01 Steve Patterson
# (348, 24)
# 3307
# patteto01 Tom Patterson
# (25, 25)
# 3308
# pattewo01 Worthy Patterson
# (4, 22)
# 3309
# df shape (96907, 31)
# pattoju01 Justin Patton
# (204, 29)
# 3310
# paulbr01 Brandon Paul
# (87, 31)
# 3311
# paulch01 Chris Paul
# (1303, 31)
# 3312
# paulkch01 Charlie Paulk
# (121, 23)
# 3313
# paulsje01 Jerry Paulson
# (6, 22)
# 3314
# paultbi01 Billy Paultz
# (1250, 30)
# 3315
# pavloal01 Sasha Pavlović
# (807, 30)
# 3316
# paxsoji01 Jim Paxson
# (145, 23)
# 3317
# paxsoji02 Jim Paxson
# (837, 30)
# 3318
# paxsojo01 John Paxson
# (891, 30)
# 3319
# df shape (102558, 31)
# payakjo01 Johnny Payak
# (117, 22)
# 3320
# paynead01 Adreian Payne
# (294, 29)
# 3321
# payneca01 Cameron Payne
# (318, 31)
# 3322
# payneke01 Kenny Payne
# (144, 30)
# 3323
# payneto01 Tom Payne
# (30, 23)
# 3324
# paytoel01 Elfrid Payton
# (473, 29)
# 3325
# paytoga01 Gary Payton*
# (1513, 30)
# 3326
# paytoga02 Gary Payton
# (116, 29)
# 3327
# paytome01 Mel Payton
# (116, 23)
# 3328
# pearcge01 George Pearcy
# (32, 22)
# 3329
# df shape (105711, 31)
# pearche01 Henry Pearcy
# (28, 22)
# 3330
# pecheol01 Oleksiy Pecherov
# (249, 30)
# 3331
# peckwi01 Wiley Peck
# (54, 29)
# 3332
# peekri01 Rich Peek
# (50, 26)
# 3333
# peelean01 Anthony Peeler
# (954, 30)
# 3334
# peeplge01 George Peeples
# (329, 28)
# 3335
# pekovni01 Nikola Peković
# (476, 29)
# 3336
# pelkija01 Jake Pelkington
# (57, 23)
# 3337
# pelleno01 Norvel Pelle
# (65, 29)
# 3338
# pellosa01 Sam Pellom
# (201, 29)
# 3339
# df shape (108174, 31)
# penbemi01 Mike Penberthy
# (61, 29)
# 3340
# pendeje01 Jerry Pender
# (11, 27)
# 3341
# penigde01 Desmond Penigar
# (10, 29)
# 3342
# penneki01 Kirk Penney
# (7, 29)
# 3343
# peplomi01 Mike Peplowski
# (68, 29)
# 3344
# perduwi01 Will Perdue
# (985, 30)
# 3345
# perkike01 Kendrick Perkins
# (1190, 31)
# 3346
# perkisa01 Sam Perkins
# (1464, 30)
# 3347
# perkiwa01 Warren Perkins
# (126, 23)
# 3348
# perovko01 Kosta Perović
# (82, 29)
# 3349
# df shape (112178, 31)
# perralo01 London Perrantes
# (81, 29)
# 3350
# perryau01 Aulcie Perry
# (21, 27)
# 3351
# perrycu01 Curtis Perry
# (533, 28)
# 3352
# perryel01 Elliot Perry
# (631, 30)
# 3353
# perryro01 Ron Perry
# (187, 26)
# 3354
# perryti01 Tim Perry
# (504, 30)
# 3355
# persoch01 Chuck Person
# (1010, 30)
# 3356
# persowe01 Wesley Person
# (844, 30)
# 3357
# peteral01 Alec Peters
# (82, 29)
# 3358
# peterji01 Jim Petersen
# (537, 30)
# 3359
# df shape (116608, 31)
# peterlo01 Loy Petersen
# (68, 22)
# 3360
# peterbo01 Bob Peterson
# (106, 23)
# 3361
# petered01 Ed Peterson
# (115, 23)
# 3362
# peterme01 Mel Peterson
# (148, 26)
# 3363
# petermo01 Morris Peterson
# (892, 30)
# 3364
# petrige01 Geoff Petrie
# (446, 24)
# 3365
# petrojo01 Johan Petro
# (662, 30)
# 3366
# petrodr01 Dražen Petrović*
# (319, 30)
# 3367
# petruri01 Richard Petruška
# (22, 29)
# 3368
# pettibo01 Bob Pettit*
# (880, 23)
# 3369
# df shape (120266, 31)
# pettwje01 Jerry Pettway
# (89, 26)
# 3370
# pheglro01 Roger Phegley
# (359, 29)
# 3371
# phelaja01 Jack Phelan
# (54, 23)
# 3372
# phelaja02 James Phelan
# (4, 22)
# 3373
# phelpde01 Derrick Phelps
# (3, 29)
# 3374
# phelpmi01 Michael Phelps
# (132, 29)
# 3375
# phillan01 Andy Phillip*
# (769, 23)
# 3376
# philled01 Eddie Phillips
# (50, 29)
# 3377
# phillga01 Gary Phillips
# (366, 23)
# 3378
# phillge01 Gene Phillips
# (31, 28)
# 3379
# df shape (122123, 31)
# phillbo01 Bobby Phills
# (515, 30)
# 3380
# piatker01 Eric Piatkowski
# (1074, 30)
# 3381
# piatkwa01 Walter Piatkowski
# (168, 27)
# 3382
# piercpa01 Paul Pierce
# (1671, 31)
# 3383
# piercri01 Ricky Pierce
# (1097, 30)
# 3384
# pietkst01 Stan Pietkiewicz
# (96, 28)
# 3385
# pietrmi01 Mickaël Piétrus
# (843, 30)
# 3386
# pilchjo01 John Pilch
# (9, 22)
# 3387
# pincked01 Ed Pinckney
# (855, 30)
# 3388
# pinknke01 Kevinn Pinkney
# (7, 29)
# 3389
# df shape (128458, 31)
# pinonjo01 John Pinone
# (7, 28)
# 3390
# pinsoth01 Theo Pinson
# (151, 31)
# 3391
# piontda01 Dave Piontek
# (437, 23)
# 3392
# piotrto01 Tom Piotrowski
# (18, 28)
# 3393
# pippesc01 Scottie Pippen*
# (1424, 30)
# 3394
# pittmch01 Charles Pittman
# (255, 30)
# 3395
# pittmde01 Dexter Pittman
# (231, 30)
# 3396
# planizo01 Zoran Planinić
# (217, 30)
# 3397
# pleisti01 Tibor Pleiß
# (82, 29)
# 3398
# plumlma02 Marshall Plumlee
# (121, 29)
# 3399
# df shape (131401, 31)
# plumlma01 Mason Plumlee
# (600, 31)
# 3400
# plumlmi01 Miles Plumlee
# (597, 31)
# 3401
# plummga01 Gary Plummer
# (126, 29)
# 3402
# podkopa01 Pavel Podkolzin
# (94, 29)
# 3403
# poirivi01 Vincent Poirier
# (64, 29)
# 3404
# poleedw01 Dwayne Polee
# (1, 29)
# 3405
# pollaji01 Jim Pollard*
# (510, 23)
# 3406
# pollasc01 Scot Pollard
# (857, 30)
# 3407
# polsora01 Ralph Polson
# (48, 22)
# 3408
# poeltja01 Jakob Pöltl
# (336, 31)
# 3409
# df shape (134634, 31)
# polynol01 Olden Polynice
# (1116, 30)
# 3410
# pondecl01 Cliff Pondexter
# (200, 28)
# 3411
# pondequ01 Quincy Pondexter
# (735, 31)
# 3412
# pondssh01 Shamorie Ponds
# (38, 29)
# 3413
# poolejo01 Jordan Poole
# (65, 29)
# 3414
# popeda01 David Pope
# (33, 29)
# 3415
# popema01 Mark Pope
# (247, 30)
# 3416
# popsoda01 Dave Popson
# (41, 29)
# 3417
# poquebe01 Ben Poquette
# (722, 30)
# 3418
# portech01 Chris Porter
# (82, 29)
# 3419
# df shape (137913, 31)
# porteho01 Howard Porter
# (492, 28)
# 3420
# porteke01 Kevin Porter
# (692, 29)
# 3421
# porteke02 Kevin Porter
# (65, 29)
# 3422
# portemi01 Michael Porter
# (65, 29)
# 3423
# porteot01 Otto Porter
# (597, 31)
# 3424
# portete01 Terry Porter
# (1406, 30)
# 3425
# portewi01 Willie Porter
# (68, 26)
# 3426
# portibo01 Bobby Portis
# (400, 30)
# 3427
# portmbo01 Bob Portman
# (230, 23)
# 3428
# porzikr01 Kristaps Porziņģis
# (394, 29)
# 3429
# df shape (142322, 31)
# poseyja01 James Posey
# (1021, 30)
# 3430
# postela01 Lavor Postell
# (201, 29)
# 3431
# postljo01 John Postley
# (1, 25)
# 3432
# potapvi01 Vitaly Potapenko
# (835, 30)
# 3433
# powele01 Leon Powe
# (436, 30)
# 3434
# powelci01 Cincinnatus Powell
# (660, 28)
# 3435
# poweldw01 Dwight Powell
# (483, 31)
# 3436
# poweljo01 Josh Powell
# (544, 31)
# 3437
# powelka01 Kasib Powell
# (11, 29)
# 3438
# powelno01 Norman Powell
# (456, 31)
# 3439
# df shape (146970, 31)
# powelro01 Roger Powell
# (33, 29)
# 3440
# poythal01 Alex Poythress
# (170, 29)
# 3441
# praddma01 Marlbert Pradd
# (86, 26)
# 3442
# prattmi01 Mike Pratt
# (168, 27)
# 3443
# presspa01 Paul Pressey
# (799, 30)
# 3444
# pressph01 Phil Pressey
# (195, 31)
# 3445
# pressdo01 Dominic Pressley
# (13, 29)
# 3446
# pressha01 Harold Pressley
# (299, 29)
# 3447
# previst01 Stephen Previs
# (30, 28)
# 3448
# priceaj01 A.J. Price
# (433, 30)
# 3449
# df shape (149196, 31)
# pricebr01 Brent Price
# (544, 30)
# 3450
# priceji01 Jim Price
# (533, 28)
# 3451
# pricema01 Mark Price
# (784, 30)
# 3452
# pricemi01 Mike Price
# (119, 27)
# 3453
# pricero01 Ronnie Price
# (922, 30)
# 3454
# priceto01 Tony Price
# (5, 28)
# 3455
# priddbo01 Bob Priddy
# (17, 23)
# 3456
# prigipa01 Pablo Prigioni
# (363, 31)
# 3457
# princta01 Tayshaun Prince
# (1273, 30)
# 3458
# pritcjo01 John Pritchard
# (7, 22)
# 3459
# df shape (153763, 31)
# pritcke01 Kevin Pritchard
# (94, 29)
# 3460
# profila01 Laron Profit
# (211, 30)
# 3461
# pruitga01 Gabe Pruitt
# (164, 30)
# 3462
# przybjo01 Joel Przybilla
# (943, 31)
# 3463
# pughle01 Les Pugh
# (112, 22)
# 3464
# pughro01 Roy Pugh
# (22, 22)
# 3465
# pullaan01 Anthony Pullard
# (8, 29)
# 3466
# pulleja01 Jacob Pullen
# (37, 29)
# 3467
# purviro01 Rodney Purvis
# (17, 29)
# 3468
# putnado01 Don Putman
# (221, 23)
# 3469
# df shape (155592, 31)
# qizh01 Zhou Qi
# (110, 31)
# 3470
# quartti01 Tim Quarterman
# (90, 31)
# 3471
# quickbo01 Bob Quick
# (137, 27)
# 3472
# quinnch01 Chris Quinn
# (424, 30)
# 3473
# quinnbr01 Brian Quinnett
# (144, 30)
# 3474
# rabbiv01 Ivan Rabb
# (164, 29)
# 3475
# rackllu01 Luther Rackley
# (220, 28)
# 3476
# radjadi01 Dino Rađa*
# (235, 30)
# 3477
# raderho01 Howie Rader
# (12, 22)
# 3478
# radfoma01 Mark Radford
# (97, 28)
# 3479
# df shape (157225, 31)
# radfowa01 Wayne Radford
# (52, 27)
# 3480
# radmavl01 Vladimir Radmanović
# (987, 31)
# 3481
# radojal01 Aleksandar Radojević
# (25, 29)
# 3482
# radovfr01 Frank Radovich
# (35, 23)
# 3483
# radovmo01 Moe Radovich
# (4, 22)
# 3484
# radulmi01 Miroslav Raduljica
# (92, 29)
# 3485
# radzira01 Ray Radziszewski
# (1, 22)
# 3486
# ragelra01 Ray Ragelis
# (49, 23)
# 3487
# raikesh01 Sherwin Raiken
# (0, 23)
# 3488
# rainsed01 Ed Rains
# (91, 29)
# 3489
# df shape (158561, 31)
# rakocig01 Igor Rakočević
# (74, 29)
# 3490
# rambiku01 Kurt Rambis
# (1019, 30)
# 3491
# ramospe01 Peter John Ramos
# (24, 29)
# 3492
# ramseca01 Cal Ramsey
# (13, 22)
# 3493
# ramsefr01 Frank Ramsey*
# (720, 23)
# 3494
# ramsera01 Ray Ramsey
# (1, 22)
# 3495
# randama01 Mark Randall
# (129, 30)
# 3496
# randlch01 Chasson Randle
# (105, 29)
# 3497
# randlju01 Julius Randle
# (476, 29)
# 3498
# randoan01 Anthony Randolph
# (479, 31)
# 3499
# df shape (161601, 31)
# randosh01 Shavlik Randolph
# (499, 31)
# 3500
# randoza01 Zach Randolph
# (1408, 31)
# 3501
# rankwa01 Wally Rank
# (25, 28)
# 3502
# ranseke01 Kelvin Ransey
# (488, 30)
# 3503
# ranzisa01 Sam Ranzino
# (36, 22)
# 3504
# rascobo01 Bobby Rascoe
# (170, 26)
# 3505
# rasmubl01 Blair Rasmussen
# (561, 30)
# 3506
# rathaxa01 Xavier Rathan-Mayes
# (5, 29)
# 3507
# ratkoge01 George Ratkovicz
# (366, 23)
# 3508
# ratleed01 Ed Ratleff
# (338, 28)
# 3509
# df shape (165497, 31)
# ratlimi01 Mike Ratliff
# (60, 24)
# 3510
# ratlith01 Theo Ratliff
# (1215, 30)
# 3511
# rautian01 Andy Rautins
# (82, 29)
# 3512
# rautile01 Leo Rautins
# (35, 30)
# 3513
# rayal01 Allan Ray
# (82, 29)
# 3514
# raycl01 Clifford Ray
# (843, 29)
# 3515
# raydo01 Don Ray
# (61, 23)
# 3516
# rayja01 James Ray
# (107, 29)
# 3517
# rayji01 Jim Ray
# (10, 22)
# 3518
# raylji01 Jimmy Rayl
# (103, 26)
# 3519
# df shape (168095, 31)
# raymocr01 Craig Raymond
# (263, 28)
# 3520
# reaco01 Connie Rea
# (20, 22)
# 3521
# reavejo01 Joe Reaves
# (7, 27)
# 3522
# reavejo02 Josh Reaves
# (67, 29)
# 3523
# rebraze01 Željko Rebrača
# (358, 30)
# 3524
# recasel01 Eldridge Recasner
# (408, 30)
# 3525
# reddmi01 Michael Redd
# (905, 30)
# 3526
# reddica01 Cam Reddish
# (67, 29)
# 3527
# reddofr01 Frank Reddout
# (7, 22)
# 3528
# redicjj01 J.J. Redick
# (1225, 30)
# 3529
# df shape (171422, 31)
# redmoma01 Marlon Redmond
# (78, 29)
# 3530
# reedda01 Davon Reed
# (163, 29)
# 3531
# reedhu01 Hub Reed
# (495, 23)
# 3532
# reedju01 Justin Reed
# (217, 30)
# 3533
# reedro01 Ron Reed
# (118, 22)
# 3534
# reedwi02 Willie Reed
# (218, 29)
# 3535
# reedwi01 Willis Reed*
# (728, 25)
# 3536
# reevebr01 Bryant Reeves
# (425, 29)
# 3537
# reevekh01 Khalid Reeves
# (319, 29)
# 3538
# reganri01 Richie Regan
# (217, 23)
# 3539
# df shape (174400, 31)
# rehfedo01 Don Rehfeldt
# (98, 22)
# 3540
# reidbi01 Billy Reid
# (59, 28)
# 3541
# reiddo01 Don Reid
# (530, 30)
# 3542
# reidjr01 J.R. Reid
# (758, 30)
# 3543
# reidji01 Jim Reid
# (6, 22)
# 3544
# reidna01 Naz Reid
# (64, 29)
# 3545
# reidro01 Robert Reid
# (998, 30)
# 3546
# reidry01 Ryan Reid
# (46, 29)
# 3547
# reineja01 Jared Reiner
# (92, 30)
# 3548
# reisech01 Chick Reiser
# (188, 23)
# 3549
# df shape (177239, 31)
# rellfri01 Richard Rellford
# (4, 29)
# 3550
# renchte01 Terrence Rencher
# (36, 29)
# 3551
# rennijo01 John Rennicke
# (6, 22)
# 3552
# rensbro01 Bob Rensberger
# (3, 22)
# 3553
# rentzef01 Efthimi Rentzias
# (77, 29)
# 3554
# respesh01 Shawn Respert
# (231, 29)
# 3555
# restake01 Kevin Restani
# (559, 29)
# 3556
# reynoca01 Cameron Reynolds
# (22, 29)
# 3557
# reynoge01 George Reynolds
# (10, 22)
# 3558
# reynoje01 Jerry Reynolds
# (461, 30)
# 3559
# df shape (178648, 31)
# rhineke01 Kendall Rhine
# (128, 26)
# 3560
# rhodege01 Gene Rhodes
# (66, 23)
# 3561
# rhodero01 Rodrick Rhodes
# (117, 30)
# 3562
# ricegl01 Glen Rice
# (1087, 30)
# 3563
# ricegl02 Glen Rice
# (116, 29)
# 3564
# richach01 Chris Richard
# (111, 30)
# 3565
# richacl01 Clint Richardson
# (658, 30)
# 3566
# richaja01 Jason Richardson
# (1167, 30)
# 3567
# richaje01 Jeremy Richardson
# (151, 30)
# 3568
# richajo01 Josh Richardson
# (412, 30)
# 3569
# df shape (182661, 31)
# richama01 Malachi Richardson
# (218, 29)
# 3570
# richami01 Micheal Ray Richardson
# (574, 30)
# 3571
# richano01 Norm Richardson
# (18, 29)
# 3572
# richapo01 Pooh Richardson
# (687, 30)
# 3573
# richaqu01 Quentin Richardson
# (997, 31)
# 3574
# richmmi01 Mitch Richmond*
# (1043, 30)
# 3575
# richtjo01 John Richter
# (65, 23)
# 3576
# rickedi01 Dick Ricketts
# (214, 23)
# 3577
# rideris01 Isaiah Rider
# (614, 30)
# 3578
# ridglja01 Jackie Ridgle
# (31, 22)
# 3579
# df shape (187122, 31)
# ridnolu01 Luke Ridnour
# (988, 30)
# 3580
# riebeme01 Mel Riebe
# (152, 23)
# 3581
# riedybo01 Bob Riedy
# (22, 25)
# 3582
# riffeji01 Jim Riffey
# (34, 22)
# 3583
# rigauan01 Antoine Rigaudeau
# (21, 29)
# 3584
# rikerto01 Tom Riker
# (82, 25)
# 3585
# rileybo01 Bob Riley
# (8, 22)
# 3586
# rileyer01 Eric Riley
# (218, 29)
# 3587
# rileypa01 Pat Riley*
# (572, 25)
# 3588
# rileyro01 Ron Riley
# (264, 25)
# 3589
# df shape (189483, 31)
# rinalri01 Rich Rinaldi
# (82, 28)
# 3590
# riordmi01 Mike Riordan
# (721, 25)
# 3591
# risenar01 Arnie Risen*
# (697, 23)
# 3592
# rittete01 Tex Ritter
# (159, 23)
# 3593
# rivasra01 Ramón Rivas
# (28, 29)
# 3594
# riverau01 Austin Rivers
# (674, 31)
# 3595
# riverda01 David Rivers
# (114, 30)
# 3596
# riverdo01 Doc Rivers
# (945, 30)
# 3597
# robbile01 Lee Robbins
# (44, 22)
# 3598
# robbire01 Red Robbins
# (652, 28)
# 3599
# df shape (193599, 31)
# roberan03 Andre Roberson
# (463, 31)
# 3600
# roberan02 Anthony Roberson
# (198, 30)
# 3601
# roberri01 Rick Roberson
# (441, 25)
# 3602
# roberte01 Terrance Roberson
# (12, 29)
# 3603
# roberan01 Anthony Roberts
# (229, 29)
# 3604
# roberbi01 Bill Roberts
# (111, 23)
# 3605
# roberbr01 Brian Roberts
# (409, 31)
# 3606
# roberfr01 Fred Roberts
# (907, 30)
# 3607
# roberjo01 Joe Roberts
# (231, 26)
# 3608
# roberla01 Lawrence Roberts
# (164, 29)
# 3609
# df shape (196764, 31)
# roberma01 Marv Roberts
# (424, 28)
# 3610
# roberst01 Stanley Roberts
# (332, 30)
# 3611
# roberal01 Alvin Robertson
# (792, 30)
# 3612
# roberos01 Oscar Robertson*
# (1126, 25)
# 3613
# roberry01 Ryan Robertson
# (1, 29)
# 3614
# roberto01 Tony Robertson
# (77, 28)
# 3615
# robeyri01 Rick Robey
# (546, 30)
# 3616
# robinbe01 Bernard Robinson
# (213, 30)
# 3617
# robinch01 Chris Robinson
# (110, 29)
# 3618
# robincl01 Cliff Robinson
# (646, 30)
# 3619
# df shape (201031, 31)
# robincl02 Clifford Robinson
# (1571, 30)
# 3620
# robinda01 David Robinson*
# (1133, 30)
# 3621
# robinde01 Devin Robinson
# (164, 29)
# 3622
# robindu01 Duncan Robinson
# (147, 29)
# 3623
# robined01 Eddie Robinson
# (381, 30)
# 3624
# robinfl01 Flynn Robinson
# (571, 28)
# 3625
# robingl01 Glenn Robinson
# (786, 30)
# 3626
# robingl02 Glenn Robinson
# (496, 31)
# 3627
# robinja01 Jackie Robinson
# (22, 28)
# 3628
# robinja03 Jamal Robinson
# (13, 29)
# 3629
# df shape (206315, 31)
# robinja02 James Robinson
# (436, 30)
# 3630
# robinje01 Jerome Robinson
# (154, 31)
# 3631
# robinju01 Justin Robinson
# (35, 29)
# 3632
# robinla01 Larry Robinson
# (104, 29)
# 3633
# robinmi01 Mitchell Robinson
# (148, 29)
# 3634
# robinna01 Nate Robinson
# (799, 30)
# 3635
# robinol01 Oliver Robinson
# (35, 28)
# 3636
# robinro01 Ronnie Robinson
# (71, 27)
# 3637
# robinru01 Rumeal Robinson
# (377, 30)
# 3638
# robinsa01 Samuel Robinson
# (140, 27)
# 3639
# df shape (208614, 31)
# robinth01 Thomas Robinson
# (424, 31)
# 3640
# robintr01 Truck Robinson
# (846, 30)
# 3641
# robinwa01 Wayne Robinson
# (80, 28)
# 3642
# robinwi01 Wilbert Robinson
# (46, 27)
# 3643
# robinbi01 Bill Robinzine
# (537, 29)
# 3644
# robisda01 Dave Robisch
# (972, 29)
# 3645
# robyis01 Isaiah Roby
# (63, 29)
# 3646
# rochare01 Red Rocha
# (626, 23)
# 3647
# rochejo01 John Roche
# (498, 29)
# 3648
# rockge01 Gene Rock
# (0, 23)
# 3649
# df shape (212706, 31)
# rockeja01 Jack Rocker
# (8, 22)
# 3650
# rodgegu01 Guy Rodgers*
# (937, 23)
# 3651
# rodmade01 Dennis Rodman*
# (1092, 30)
# 3652
# rodrise01 Sergio Rodríguez
# (414, 30)
# 3653
# roelo01 Lou Roe
# (106, 30)
# 3654
# rogerca01 Carlos Rogers
# (430, 29)
# 3655
# rogerha01 Harry Rogers
# (18, 27)
# 3656
# rogerjo01 Johnny Rogers
# (69, 29)
# 3657
# rogerma01 Marshall Rogers
# (27, 25)
# 3658
# rogerro01 Rodney Rogers
# (975, 30)
# 3659
# df shape (216782, 31)
# rogerro02 Roy Rogers
# (183, 29)
# 3660
# rogerwi01 Willie Rogers
# (37, 25)
# 3661
# rogesal01 Al Roges
# (71, 22)
# 3662
# rohloke01 Ken Rohloff
# (2, 22)
# 3663
# rollike01 Kenny Rollins
# (173, 23)
# 3664
# rolliph01 Phil Rollins
# (175, 22)
# 3665
# rollitr01 Tree Rollins
# (1249, 30)
# 3666
# romarlo01 Lorenzo Romar
# (291, 30)
# 3667
# rondora01 Rajon Rondo
# (1226, 31)
# 3668
# rookje01 Jerry Rook
# (29, 25)
# 3669
# df shape (220218, 31)
# rooksse01 Sean Rooks
# (907, 30)
# 3670
# rosede01 Derrick Rose
# (1003, 31)
# 3671
# roseja01 Jalen Rose
# (1072, 30)
# 3672
# rosema01 Malik Rose
# (1094, 30)
# 3673
# rosero01 Rob Rose
# (2, 29)
# 3674
# rosenpe01 Petey Rosenberg
# (49, 23)
# 3675
# rosenle01 Lennie Rosenbluth
# (82, 23)
# 3676
# rosenha01 Hank Rosenstein
# (59, 22)
# 3677
# rosendi01 Dick Rosenthal
# (84, 23)
# 3678
# rossqu01 Quinton Ross
# (569, 30)
# 3679
# df shape (225139, 31)
# rosste01 Terrence Ross
# (673, 30)
# 3680
# rothdo01 Doug Roth
# (42, 29)
# 3681
# rothsc01 Scott Roth
# (160, 30)
# 3682
# rotheir01 Irv Rothenberg
# (142, 23)
# 3683
# rottnmi01 Mickey Rottner
# (110, 23)
# 3684
# roundda01 Dan Roundfield
# (853, 30)
# 3685
# rouxgi01 Giff Roux
# (157, 23)
# 3686
# rowanro01 Ron Rowan
# (7, 29)
# 3687
# rowecu01 Curtis Rowe
# (618, 28)
# 3688
# rowinji01 Jim Rowinski
# (23, 29)
# 3689
# df shape (227924, 31)
# rowlade01 Derrick Rowland
# (2, 29)
# 3690
# rowsobr01 Brian Rowsom
# (82, 29)
# 3691
# roybr01 Brandon Roy
# (506, 30)
# 3692
# royaldo01 Donald Royal
# (565, 30)
# 3693
# royalre01 Reggie Royals
# (2, 27)
# 3694
# royerbo01 Bob Royer
# (40, 22)
# 3695
# roziecl01 Clifford Rozier
# (193, 29)
# 3696
# roziete01 Terry Rozier
# (445, 31)
# 3697
# rubiori01 Ricky Rubio
# (721, 31)
# 3698
# ruckegu01 Guy Rucker
# (9, 29)
# 3699
# df shape (230489, 31)
# ruddde01 Delaney Rudd
# (263, 30)
# 3700
# ruddjo01 John Rudd
# (58, 27)
# 3701
# rudezda01 Damjan Rudež
# (246, 29)
# 3702
# rudomjo01 John Rudometkin
# (129, 22)
# 3703
# ruffimi01 Michael Ruffin
# (617, 30)
# 3704
# ruffitr01 Trevor Ruffin
# (110, 30)
# 3705
# ruffnpa01 Paul Ruffner
# (132, 28)
# 3706
# ruklijo01 Joe Ruklick
# (118, 23)
# 3707
# rulanje01 Jeff Ruland
# (349, 30)
# 3708
# rulebo01 Bob Rule
# (403, 24)
# 3709
# df shape (232914, 31)
# rulloje01 Jerry Rullo
# (101, 23)
# 3710
# ruscost01 Stefano Rusconi
# (7, 29)
# 3711
# rushbr01 Brandon Rush
# (786, 31)
# 3712
# rushka01 Kareem Rush
# (529, 30)
# 3713
# russebi01 Bill Russell*
# (1128, 23)
# 3714
# russebr01 Bryon Russell
# (1042, 30)
# 3715
# russeca02 Campy Russell
# (586, 30)
# 3716
# russeca01 Cazzie Russell
# (890, 28)
# 3717
# russeda01 D'Angelo Russell
# (399, 30)
# 3718
# russefr01 Frank Russell
# (23, 22)
# 3719
# df shape (238405, 31)
# russepi01 Pierre Russell
# (110, 28)
# 3720
# russeru01 Rubin Russell
# (27, 25)
# 3721
# russewa01 Walker Russell
# (155, 30)
# 3722
# russewa02 Walker Russell
# (51, 29)
# 3723
# sabonar01 Arvydas Sabonis*
# (555, 30)
# 3724
# sabondo01 Domantas Sabonis
# (327, 31)
# 3725
# sacrero01 Robert Sacre
# (332, 31)
# 3726
# sadowed01 Ed Sadowski
# (237, 23)
# 3727
# sailoke01 Kenny Sailors
# (278, 23)
# 3728
# sallejo01 John Salley
# (919, 30)
# 3729
# df shape (241396, 31)
# salmojo01 John Salmons
# (1043, 31)
# 3730
# salvaal01 Al Salvadori
# (16, 25)
# 3731
# salvake01 Kevin Salvadori
# (77, 29)
# 3732
# samakso01 Soumaila Samake
# (93, 29)
# 3733
# samanlu01 Luka Šamanić
# (63, 29)
# 3734
# sambch01 Cheikh Samb
# (145, 29)
# 3735
# sampsbr01 Brandon Sampson
# (47, 29)
# 3736
# sampsja02 JaKarr Sampson
# (312, 29)
# 3737
# sampsja01 Jamal Sampson
# (250, 29)
# 3738
# sampsra01 Ralph Sampson*
# (494, 30)
# 3739
# df shape (243936, 31)
# samuesa01 Samardo Samuels
# (183, 29)
# 3740
# sanchpe01 Pepe Sánchez
# (91, 29)
# 3741
# sandeal01 Al Sanders
# (4, 27)
# 3742
# sandefr01 Frankie Sanders
# (68, 29)
# 3743
# sandeje01 Jeff Sanders
# (55, 30)
# 3744
# sandela01 Larry Sanders
# (380, 30)
# 3745
# sandeme01 Melvin Sanders
# (29, 29)
# 3746
# sandemi01 Mike Sanders
# (715, 30)
# 3747
# sandeto01 Tom Sanders*
# (1047, 23)
# 3748
# sanforo01 Ron Sanford
# (1, 26)
# 3749
# df shape (246509, 31)
# santida01 Daniel Santiago
# (206, 30)
# 3750
# santibo01 Bob Santini
# (4, 22)
# 3751
# sapplwa01 Wayne Sappleton
# (33, 29)
# 3752
# saricda01 Dario Šarić
# (312, 30)
# 3753
# sasseja01 Jason Sasser
# (23, 29)
# 3754
# sasseje01 Jeryl Sasser
# (101, 30)
# 3755
# satorto01 Tomáš Satoranský
# (330, 31)
# 3756
# satteke01 Kenny Satterfield
# (120, 29)
# 3757
# saulpe01 Pep Saul
# (420, 23)
# 3758
# sauldwo01 Woody Sauldsberry
# (492, 23)
# 3759
# df shape (248550, 31)
# saultgl01 Glynn Saulters
# (21, 25)
# 3760
# saundfr01 Fred Saunders
# (210, 28)
# 3761
# savagdo01 Don Savage
# (17, 22)
# 3762
# savovpr01 Predrag Savović
# (37, 29)
# 3763
# sawyeal01 Alan Sawyer
# (31, 22)
# 3764
# scalabr01 Brian Scalabrine
# (869, 30)
# 3765
# scaleal01 Alex Scales
# (5, 29)
# 3766
# scalede01 DeWayne Scales
# (48, 28)
# 3767
# schadfr01 Frank Schade
# (9, 22)
# 3768
# schadbe01 Ben Schadler
# (36, 23)
# 3769
# df shape (249833, 31)
# schaehe01 Herm Schaefer
# (144, 23)
# 3770
# schaebi01 Billy Schaeffer
# (137, 28)
# 3771
# schafbo01 Bob Schafer
# (62, 23)
# 3772
# scharbe01 Ben Scharnus
# (51, 23)
# 3773
# schatma01 Marv Schatzman
# (30, 22)
# 3774
# schaufr01 Fred Schaus
# (354, 23)
# 3775
# schayda01 Danny Schayes
# (1272, 30)
# 3776
# schaydo01 Dolph Schayes*
# (1093, 23)
# 3777
# schecos01 Ossie Schectman
# (52, 22)
# 3778
# schefst01 Steve Scheffler
# (194, 30)
# 3779
# df shape (253222, 31)
# schefto01 Tom Scheffler
# (42, 30)
# 3780
# schelda01 Dave Schellhase
# (76, 23)
# 3781
# schenlu01 Luke Schenscher
# (45, 30)
# 3782
# scherhe01 Herb Scherer
# (30, 22)
# 3783
# schindw01 Dwayne Schintzius
# (265, 30)
# 3784
# schluda01 Dale Schlueter
# (602, 28)
# 3785
# schneot01 Otto Schnellbacher
# (44, 23)
# 3786
# schnidi01 Dick Schnittker
# (399, 23)
# 3787
# schoeru01 Russ Schoene
# (312, 30)
# 3788
# schofad01 Admiral Schofield
# (64, 29)
# 3789
# df shape (255101, 31)
# scholda01 Dave Scholz
# (1, 22)
# 3790
# schoomi01 Milt Schoon
# (102, 23)
# 3791
# schrede01 Detlef Schrempf
# (1272, 30)
# 3792
# schrode01 Dennis Schröder
# (600, 31)
# 3793
# schulho01 Howie Schultz
# (188, 23)
# 3794
# schuldi01 Dick Schulz
# (226, 23)
# 3795
# schurro01 Roger Schurig
# (20, 25)
# 3796
# schwejo01 John Schweitz
# (22, 29)
# 3797
# scolalu01 Luis Scola
# (838, 31)
# 3798
# scolafr01 Fred Scolari
# (575, 23)
# 3799
# df shape (258945, 31)
# scottal01 Alvin Scott
# (688, 30)
# 3800
# scottbr01 Brent Scott
# (41, 29)
# 3801
# scottby01 Byron Scott
# (1259, 30)
# 3802
# scottch01 Charlie Scott*
# (689, 29)
# 3803
# scottde01 Dennis Scott
# (690, 30)
# 3804
# scottja01 James Scott
# (21, 29)
# 3805
# scottmi01 Mike Scott
# (671, 31)
# 3806
# scottra01 Ray Scott
# (859, 27)
# 3807
# scottsh01 Shawnelle Scott
# (206, 30)
# 3808
# scottwi01 Willie Scott
# (8, 25)
# 3809
# df shape (264077, 31)
# scranpa01 Paul Scranton
# (6, 25)
# 3810
# scurrca01 Carey Scurry
# (188, 30)
# 3811
# sealsbr01 Bruce Seals
# (381, 29)
# 3812
# sealssh01 Shea Seals
# (8, 29)
# 3813
# sealyma01 Malik Sealy
# (514, 30)
# 3814
# searced01 Ed Searcy
# (4, 24)
# 3815
# searske01 Kenny Sears
# (538, 23)
# 3816
# seewa01 Wayne See
# (60, 22)
# 3817
# sefolth01 Thabo Sefolosha
# (1244, 31)
# 3818
# seikaro01 Rony Seikaly
# (748, 30)
# 3819
# df shape (267768, 31)
# selbogl01 Glen Selbo
# (12, 22)
# 3820
# selbyjo01 Josh Selby
# (124, 30)
# 3821
# seldewa01 Wayne Selden
# (187, 30)
# 3822
# sellebr01 Brad Sellers
# (426, 30)
# 3823
# selleph01 Phil Sellers
# (45, 25)
# 3824
# seltzro01 Rollie Seltz
# (34, 22)
# 3825
# selvale01 Lester Selvage
# (82, 26)
# 3826
# selvyfr01 Frank Selvy
# (607, 23)
# 3827
# seminji01 Jim Seminoff
# (244, 23)
# 3828
# senesa01 Mouhamed Sene
# (221, 29)
# 3829
# df shape (269750, 31)
# senesge01 George Senesky
# (512, 23)
# 3830
# serapke01 Kevin Séraphin
# (583, 31)
# 3831
# sesayan01 Ansu Sesay
# (164, 30)
# 3832
# sessira01 Ramon Sessions
# (896, 31)
# 3833
# seungha01 Ha Seung-Jin
# (117, 29)
# 3834
# sewelto01 Tom Sewell
# (21, 29)
# 3835
# sextoco01 Collin Sexton
# (147, 29)
# 3836
# seymopa01 Paul Seymour
# (687, 23)
# 3837
# shabani01 Nick Shaback
# (54, 23)
# 3838
# shackly01 Lynn Shackelford
# (19, 25)
# 3839
# df shape (272950, 31)
# shackch01 Charles Shackleford
# (321, 29)
# 3840
# shaefca01 Carl Shaeffer
# (49, 23)
# 3841
# shaffle01 Lee Shaffer
# (209, 23)
# 3842
# shakumu01 Mustafa Shakur
# (39, 29)
# 3843
# shamela01 Landry Shamet
# (151, 30)
# 3844
# shammgo01 God Shammgod
# (36, 29)
# 3845
# shannea01 Earl Shannon
# (132, 22)
# 3846
# shannho01 Howie Shannon
# (121, 22)
# 3847
# sharech01 Chuck Share
# (649, 23)
# 3848
# sharmbi01 Bill Sharman*
# (789, 23)
# 3849
# df shape (275446, 31)
# sharpwa01 Walter Sharpe
# (82, 29)
# 3850
# shaskjo01 John Shasky
# (136, 29)
# 3851
# shavlro01 Ron Shavlik
# (8, 22)
# 3852
# shawbr01 Brian Shaw
# (1124, 30)
# 3853
# shawca01 Casey Shaw
# (19, 29)
# 3854
# shayoma01 Marial Shayok
# (65, 29)
# 3855
# sheabo01 Bob Shea
# (41, 22)
# 3856
# shefffr01 Fred Sheffield
# (22, 22)
# 3857
# sheltcr01 Craig Shelton
# (60, 28)
# 3858
# sheltlo01 Lonnie Shelton
# (725, 30)
# 3859
# df shape (277728, 31)
# shengto01 Tornike Shengelia
# (161, 29)
# 3860
# shephbi01 Billy Shepherd
# (179, 28)
# 3861
# sheppje01 Jeff Sheppard
# (38, 30)
# 3862
# sheppst01 Steve Sheppard
# (104, 27)
# 3863
# sheroed01 Ed Sherod
# (70, 29)
# 3864
# shippch01 Charley Shipp
# (22, 22)
# 3865
# shirlpa01 Paul Shirley
# (61, 29)
# 3866
# shortge01 Gene Short
# (34, 24)
# 3867
# shortpu01 Purvis Short
# (860, 30)
# 3868
# shousde01 Dexter Shouse
# (3, 29)
# 3869
# df shape (279260, 31)
# shriddi01 Dick Shrider
# (4, 22)
# 3870
# shuege01 Gene Shue
# (730, 23)
# 3871
# shumajo01 John Shumate
# (330, 29)
# 3872
# shumpim01 Iman Shumpert
# (739, 31)
# 3873
# shvedal01 Alexey Shved
# (245, 29)
# 3874
# siakapa01 Pascal Siakam
# (354, 31)
# 3875
# siberjo01 Jordan Sibert
# (5, 29)
# 3876
# sibersa01 Sam Sibert
# (5, 22)
# 3877
# siblema01 Mark Sibley
# (29, 24)
# 3878
# sichtje01 Jerry Sichting
# (645, 30)
# 3879
# df shape (282346, 31)
# sidledo01 Donald Sidle
# (335, 27)
# 3880
# siegfla01 Larry Siegfried
# (629, 23)
# 3881
# siewera01 Ralph Siewert
# (21, 22)
# 3882
# sikmaja01 Jack Sikma*
# (1209, 30)
# 3883
# silasja01 James Silas
# (726, 29)
# 3884
# silaspa01 Paul Silas
# (1416, 29)
# 3885
# silasxa01 Xavier Silas
# (8, 30)
# 3886
# silerga01 Garret Siler
# (82, 29)
# 3887
# sillimi01 Mike Silliman
# (35, 22)
# 3888
# silvach01 Chris Silva
# (65, 29)
# 3889
# df shape (286872, 31)
# simiewa01 Wayne Simien
# (164, 30)
# 3890
# simmobe01 Ben Simmons
# (251, 30)
# 3891
# simmobo01 Bobby Simmons
# (695, 30)
# 3892
# simmoce01 Cedric Simmons
# (244, 29)
# 3893
# simmoco01 Connie Simmons
# (648, 23)
# 3894
# simmogr01 Grant Simmons
# (99, 26)
# 3895
# simmojo01 Johnny Simmons
# (55, 22)
# 3896
# simmojo02 Jonathon Simmons
# (367, 31)
# 3897
# simmoko01 Kobi Simmons
# (85, 29)
# 3898
# simmoli01 Lionel Simmons
# (458, 30)
# 3899
# df shape (289938, 31)
# simonmi01 Miles Simon
# (26, 29)
# 3900
# simonwa01 Walter Simon
# (599, 28)
# 3901
# simonan01 Anfernee Simons
# (148, 31)
# 3902
# simpkdi01 Dickey Simpkins
# (373, 30)
# 3903
# simpsra01 Ralph Simpson
# (759, 29)
# 3904
# simsal01 Alvin Sims
# (4, 29)
# 3905
# simsbo01 Bob Sims
# (67, 25)
# 3906
# simsco01 Courtney Sims
# (42, 29)
# 3907
# simsdo01 Doug Sims
# (4, 22)
# 3908
# simshe01 Henry Sims
# (183, 29)
# 3909
# df shape (292143, 31)
# simssc01 Scott Sims
# (12, 27)
# 3910
# singlky01 Kyle Singler
# (521, 31)
# 3911
# singlse01 Sean Singletary
# (84, 29)
# 3912
# singlch01 Chris Singleton
# (230, 29)
# 3913
# singlja01 James Singleton
# (359, 30)
# 3914
# singlmc01 McKinley Singleton
# (2, 29)
# 3915
# sinicze01 Zeke Sinicola
# (12, 22)
# 3916
# sittoch01 Charlie Sitton
# (43, 29)
# 3917
# sivape01 Peyton Siva
# (82, 29)
# 3918
# skilesc01 Scott Skiles
# (602, 30)
# 3919
# df shape (294090, 31)
# skinnal01 Al Skinner
# (356, 29)
# 3920
# skinnbr01 Brian Skinner
# (879, 30)
# 3921
# skinnta01 Tal Skinner
# (160, 25)
# 3922
# skoogwh01 Whitey Skoog
# (375, 23)
# 3923
# sladeje01 Jeff Slade
# (3, 22)
# 3924
# slatere01 Reggie Slater
# (342, 30)
# 3925
# slaugji01 Jim Slaughter
# (28, 22)
# 3926
# slaugjo01 Jose Slaughter
# (63, 28)
# 3927
# slayta01 Tamar Slay
# (129, 30)
# 3928
# sloando01 Donald Sloan
# (335, 31)
# 3929
# df shape (296760, 31)
# sloanje01 Jerry Sloan*
# (806, 25)
# 3930
# slokaur01 Uroš Slokar
# (81, 29)
# 3931
# slubyto01 Tom Sluby
# (31, 29)
# 3932
# smailal01 Alen Smailagić
# (65, 29)
# 3933
# smartke01 Keith Smart
# (2, 29)
# 3934
# smartma01 Marcus Smart
# (530, 31)
# 3935
# smawlbe01 Belus Smawley
# (271, 23)
# 3936
# smileja01 Jack Smiley
# (116, 22)
# 3937
# smithad01 Adrian Smith
# (820, 27)
# 3938
# smithal01 Al Smith
# (354, 28)
# 3939
# df shape (299836, 31)
# smithbi01 Bill Smith
# (10, 22)
# 3940
# smithbi02 Bingo Smith
# (881, 29)
# 3941
# smithbo01 Bobby Smith
# (13, 22)
# 3942
# smithch01 Charles Smith
# (651, 30)
# 3943
# smithch02 Charles Smith
# (76, 30)
# 3944
# smithch04 Charles Smith
# (236, 30)
# 3945
# smithch03 Chris Smith
# (224, 29)
# 3946
# smithch05 Chris Smith
# (30, 29)
# 3947
# smithcl01 Clinton Smith
# (46, 29)
# 3948
# smithcr01 Craig Smith
# (476, 29)
# 3949
# df shape (302479, 31)
# smithde01 Deb Smith
# (48, 23)
# 3950
# smithde03 Dennis Smith
# (231, 29)
# 3951
# smithde02 Derek Smith
# (422, 30)
# 3952
# smithdo01 Don Smith
# (8, 22)
# 3953
# smithdo02 Don Smith
# (54, 24)
# 3954
# smithdo04 Donta Smith
# (130, 29)
# 3955
# smithdo03 Doug Smith
# (296, 29)
# 3956
# smithed01 Ed Smith
# (13, 22)
# 3957
# smithel01 Elmore Smith
# (575, 28)
# 3958
# smithga01 Garfield Smith
# (141, 28)
# 3959
# df shape (304397, 31)
# smithgr01 Greg Smith
# (548, 25)
# 3960
# smithgr02 Greg Smith
# (323, 31)
# 3961
# smithis01 Ish Smith
# (781, 30)
# 3962
# smithjr01 J.R. Smith
# (1319, 31)
# 3963
# smithja01 Jabari Smith
# (216, 30)
# 3964
# smithja02 Jason Smith
# (987, 31)
# 3965
# smithje01 Jerry Smith
# (6, 29)
# 3966
# smithji01 Jim Smith
# (76, 28)
# 3967
# smithjo02 Joe Smith
# (1316, 30)
# 3968
# smithjo01 John Smith
# (155, 26)
# 3969
# df shape (310124, 31)
# smithjo03 Josh Smith
# (1044, 31)
# 3970
# smithke03 Keith Smith
# (42, 29)
# 3971
# smithke02 Ken Smith
# (19, 27)
# 3972
# smithke01 Kenny Smith
# (813, 30)
# 3973
# smithla02 LaBradford Smith
# (183, 29)
# 3974
# smithla01 Larry Smith
# (913, 30)
# 3975
# smithle01 Leon Smith
# (35, 29)
# 3976
# smithmi01 Michael Smith
# (147, 30)
# 3977
# smithmi02 Michael Smith
# (463, 30)
# 3978
# smithmi03 Mike Smith
# (24, 29)
# 3979
# df shape (313807, 31)
# smithno01 Nolan Smith
# (148, 29)
# 3980
# smithot01 Otis Smith
# (382, 30)
# 3981
# smithpe01 Pete Smith
# (5, 27)
# 3982
# smithph01 Phil Smith
# (708, 29)
# 3983
# smithra01 Randy Smith
# (1000, 29)
# 3984
# smithre01 Reggie Smith
# (66, 29)
# 3985
# smithro01 Robert Smith
# (255, 30)
# 3986
# smithru01 Russ Smith
# (114, 31)
# 3987
# smithsa01 Sam Smith
# (284, 26)
# 3988
# smithsa02 Sam Smith
# (46, 28)
# 3989
# df shape (316815, 31)
# smithst01 Steve Smith
# (1113, 30)
# 3990
# smithst03 Steven Smith
# (30, 29)
# 3991
# smithst02 Stevin Smith
# (11, 29)
# 3992
# smithth01 Theron Smith
# (65, 29)
# 3993
# smithto02 Tony Smith
# (500, 30)
# 3994
# smithwi01 William Smith
# (30, 22)
# 3995
# smithwi02 Willie Smith
# (78, 28)
# 3996
# smithzh01 Zhaire Smith
# (147, 31)
# 3997
# smitsri01 Rik Smits
# (983, 30)
# 3998
# smrekmi01 Mike Smrek
# (215, 30)
# 3999
# df shape (319987, 31)
# smythjo01 Joe Smyth
# (37, 22)
#
#
# (320024, 31)

# %%
print(game_logs.shape)
# Out:
# (320024, 31)

# %%
print(game_logs.shape)
# Out:
# (329749, 31)

# %%
game_logs.tail()
# Out:
#         Rk   G        DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT   GS  \
# 320019  33  32  1954-03-08  24-290  BLB      AWAY      MLH  L (-10)  NaN
# 320020  34  33  1954-03-08  24-290  BLB      AWAY      MLH  L (-11)  NaN
# 320021  35  34  1954-03-10  24-292  BLB      HOME      SYR   L (-8)  NaN
# 320022  36  35  1954-03-13  24-295  BLB      AWAY      BOS  L (-12)  NaN
# 320023  37  36  1954-03-14  24-296  BLB      AWAY      FTW   L (-5)  NaN
#
#            MP  ...      INDEX       NAME eFG% STL% BLK% TOV% USG% GAME_SCORE  \
# 320019    NaN  ...  smythjo01  Joe Smyth  NaN  NaN  NaN  NaN  NaN        NaN
# 320020    NaN  ...  smythjo01  Joe Smyth  NaN  NaN  NaN  NaN  NaN        NaN
# 320021  16:00  ...  smythjo01  Joe Smyth  NaN  NaN  NaN  NaN  NaN        NaN
# 320022    NaN  ...  smythjo01  Joe Smyth  NaN  NaN  NaN  NaN  NaN        NaN
# 320023    NaN  ...  smythjo01  Joe Smyth  NaN  NaN  NaN  NaN  NaN        NaN
#
#         BPM Unnamed: 24
# 320019  NaN         NaN
# 320020  NaN         NaN
# 320021  NaN         NaN
# 320022  NaN         NaN
# 320023  NaN         NaN
#
# [5 rows x 31 columns]

# %%
|
# Out:
#   File "<ipython-input-13-4b37ef281455>", line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
playoff_game_logs = None

row = df.iloc[0]

player_idx = row['index']
letter = player_idx[0]
player_name = row['Player']
print(letter,player_idx,player_name)

from_yr, to_yr = row[["From","To"]].values

#playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs/"
playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs-advanced/"
webpage = urlopen(playoff_url)
html = BeautifulSoup(webpage)
tables = html.findAll('table')

if len(tables) > 0:
    table = str(html.findAll('table')[-1])
    playoff_game_logs = pd.read_html(table)[0]
    playoff_game_logs["PLAYOFF"] = 'Y'

# %%
playoff_game_logs
