# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# #### data directories

# %%
currDir = os.getcwd()
rootDir = os.path.abspath(os.path.join(currDir,'..'))

dataDir = os.path.abspath(os.path.join(rootDir,'data'))
rawDataDir = os.path.abspath(os.path.join(dataDir,'raw'))
interimDataDir = os.path.abspath(os.path.join(dataDir,'interim'))
finalDataDir = os.path.abspath(os.path.join(dataDir,'final'))

advDataDir = os.path.abspath(os.path.join(dataDir,'advanced_stats'))
errorLog = os.path.abspath(os.path.join(dataDir,'error_log'))

# %% [markdown]
# #### read player bio data

# %%
file = f"{rawDataDir}/all_NBA_ABA_players.csv"
df = pd.read_csv(file)

print("No of distinct players:",df['index'].nunique())
# Out:
# No of distinct players: 4800

# %%
df.head()
# Out:
#        index                Player  From    To  Pos    Ht     Wt  \
# 0  abdelal01        Alaa Abdelnaby  1991  1995  F-C  6-10  240.0
# 1  abdulza01       Zaid Abdul-Aziz  1969  1978  C-F   6-9  235.0
# 2  abdulka01  Kareem Abdul-Jabbar*  1970  1989    C   7-2  225.0
# 3  abdulma02    Mahmoud Abdul-Rauf  1991  2001    G   6-1  162.0
# 4  abdulta01     Tariq Abdul-Wahad  1998  2003    F   6-6  223.0
#
#          Birth Date                  Colleges
# 0     June 24, 1968                      Duke
# 1     April 7, 1946                Iowa State
# 2    April 16, 1947                      UCLA
# 3     March 9, 1969                       LSU
# 4  November 3, 1974  Michigan, San Jose State

# %% [markdown]
# #### scraping player game logs

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

#### BASIC STATS
# https://www.basketball-reference.com/players/a/abdelal01.html
# https://www.basketball-reference.com/players/a/abdelal01/gamelog/1992
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-playoffs/

#### ADVANCED STATS
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-advanced/1992/
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-playoffs-advanced/

# %%
def get_reg_season_game_logs(player_idx,letter,from_year,to_year):
    reg_season_game_logs = None
    yearly_dfs = []
    
    # SCRAPING REGULAR SEASON GAMES
    
    for year in range(from_year, to_year+1):
        #url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog/{year}"
        url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-advanced/{year}/"
        webpage = urlopen(url)
        html = BeautifulSoup(webpage)
        tables = html.findAll('table')
      
        if len(tables)==0:
            if year > 1976: continue
            else:
                aba_url = url + "/aba/"
                webpage = urlopen(aba_url)
                html = BeautifulSoup(webpage)
                aba_tables = html.findAll('table')

                if len(aba_tables)==0: continue
                else: 
                    table = str(aba_tables[-1])
                    yearly_game_log = pd.read_html(table)[0]
                    yearly_game_log["PLAYOFF"] = 'N'
                    yearly_game_log["LEAGUE"] = 'ABA'

        else:
            table = str(tables[-1])
            yearly_game_log = pd.read_html(table)[0]
            yearly_game_log["PLAYOFF"] = 'N'
            yearly_game_log["LEAGUE"] = 'NBA'

        yearly_dfs.append(yearly_game_log)        

    reg_season_game_logs = pd.concat([x for x in yearly_dfs],ignore_index=True,sort=False)
    reg_season_game_logs["PLAYOFF"] = 'N'
    reg_season_game_logs['SERIES'] = np.nan

    reg_season_game_logs.rename(columns = {'Date': 'DATE', 'Age': 'AGE', 'Tm': 'TEAM', 
                                      'Unnamed: 5': 'HOME/AWAY', 'Opp': 'OPPONENT',
                                      'Unnamed: 7': 'RESULT', 'GmSc': 'GAME_SCORE'}, inplace=True)  
    
    return reg_season_game_logs

# %%
def get_playoff_game_logs(player_idx,letter):
    
    playoff_game_logs = None
    
    #playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs/"
    playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs-advanced/"
    webpage = urlopen(playoff_url)
    html = BeautifulSoup(webpage)
    tables = html.findAll('table')
    
    if len(tables) > 0:
        table = str(html.findAll('table')[-1])
        playoff_game_logs = pd.read_html(table)[0]
        playoff_game_logs["PLAYOFF"] = 'Y'
        playoff_game_logs["AGE"] = np.nan

        playoff_game_logs.rename(columns = {'Date': 'DATE', 'Age': 'AGE', 'Tm': 'TEAM', 'Series':'SERIES',
                                          'Unnamed: 5': 'HOME/AWAY', 'Opp': 'OPPONENT',playoff_game_logs.columns[2]:'DATE',
                                          'Unnamed: 8': 'RESULT', 'GmSc': 'GAME_SCORE'}, inplace=True)
    
    return playoff_game_logs

# %%
def get_career_game_logs(player_data,verbose=True):
    
    logger = f"{errorLog}/log.txt"
    
    # PLAYER DATA
    player_idx = player_data['index']
    letter = player_idx[0]
    player_name = player_data['Player']
    from_yr, to_yr = row[["From","To"]].values

    if verbose:
        print(player_idx,player_name)
    
    # GET REGULAR SEASON GAME LOGS
    try:
        reg_season_game_logs = get_reg_season_game_logs(player_idx,letter,from_yr,to_yr)
    except:
        reg_season_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, error in regular season game logs \n")

    # GET PLAYOFF GAME LOGS
    try:
        playoff_game_logs = get_playoff_game_logs(player_idx,letter)
    except:
        playoff_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, error in playoff game logs \n")
            
        
    try:  
        # CONCATENATING REGULAR SEASON AND PLAYOFF GAMES
        career_game_logs = pd.concat([reg_season_game_logs,playoff_game_logs],ignore_index=True,sort=False)
        career_game_logs['HOME/AWAY'] = career_game_logs['HOME/AWAY'].apply(lambda x: 'AWAY' if x=='@' else 'HOME')

        # FORMAT CAREER GAME LOGS, SORT BY DATE
        career_game_logs['Rk'] = career_game_logs['Rk'].astype(str)
        career_game_logs = career_game_logs[career_game_logs['Rk'].str.isnumeric().values]

        career_game_logs.rename(columns = {'Series':'SERIES'},inplace=True)
        career_game_logs['INDEX'] = player_idx
        career_game_logs['NAME']  = player_name

        career_game_logs.sort_values('DATE',inplace=True)
        career_game_logs.reset_index(drop=True,inplace=True)

    except:
        career_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, no playoff OR regular season data \n")
        
    return career_game_logs

# %%
k, w = 4000, 4800
player_dfs = []
for num,(index, row) in enumerate(df.iloc[k:w].iterrows()):
    print(k + num)
    
    if (num + 1) % 10 == 0:
        game_logs = pd.concat([player for player in player_dfs],ignore_index=True,sort=False)
        game_logs.to_csv(f"{advDataDir}/adv_game_logs.csv",index=False)
        print("df shape",game_logs.shape)
    
    career_game_logs = get_career_game_logs(row)
    player_dfs.append(career_game_logs)
    
    try:
        print(career_game_logs.shape)
    except:
        print("both dfs are None")
    
game_logs = pd.concat([player for player in player_dfs],ignore_index=True,sort=False)
print("\n")
print(game_logs.shape)

game_logs.to_csv(f"{advDataDir}/adv_game_logs - extract {k}-{w-1}.csv"
                 ,index=False)
# Out:
# 4000
# snellto01 Tony Snell
# (602, 31)
# 4001
# snower01 Eric Snow
# (1050, 30)
# 4002
# snydedi01 Dick Snyder
# (995, 28)
# 4003
# snydeki01 Kirk Snyder
# (327, 30)
# 4004
# sobekch01 Chips Sobek
# (63, 23)
# 4005
# soberri01 Ricky Sobers
# (850, 30)
# 4006
# sobiero01 Ron Sobie
# (192, 22)
# 4007
# sojoumi01 Mike Sojourner
# (191, 24)
# 4008
# sojouwi01 Willie Sojourner
# (340, 28)
# 4009
# df shape (4610, 31)
# solomwi01 Will Solomon
# (160, 29)
# 4010
# somerwi01 Willie Somerset
# (145, 26)
# 4011
# songada01 Darius Songaila
# (676, 30)
# 4012
# sorenda01 Dave Sorenson
# (212, 22)
# 4013
# southja01 James Southerland
# (25, 29)
# 4014
# sovragi01 Gino Sovran
# (6, 22)
# 4015
# sowpa01 Pape Sow
# (193, 29)
# 4016
# spainke01 Ken Spain
# (11, 25)
# 4017
# spaldra01 Ray Spalding
# (74, 29)
# 4018
# spanaji01 Jim Spanarkel
# (259, 29)
# 4019
# df shape (6371, 31)
# spanova01 Vassilis Spanoulis
# (83, 30)
# 4020
# sparkda01 Daniel Sparks
# (67, 26)
# 4021
# sparrgu01 Guy Sparrow
# (149, 22)
# 4022
# sparrro01 Rory Sparrow
# (866, 30)
# 4023
# spearod01 Odie Spears
# (510, 23)
# 4024
# spectar01 Art Spector
# (169, 23)
# 4025
# speigma01 Marreese Speights
# (872, 31)
# 4026
# spellom01 Omari Spellman
# (148, 29)
# 4027
# spencan01 Andre Spencer
# (48, 29)
# 4028
# spencel01 Elmore Spencer
# (166, 30)
# 4029
# df shape (9449, 31)
# spencfe01 Felton Spencer
# (815, 30)
# 4030
# spicelo01 Lou Spicer
# (4, 22)
# 4031
# spitzcr01 Craig Spitzer
# (11, 23)
# 4032
# splitti01 Tiago Splitter
# (635, 31)
# 4033
# spoelar01 Art Spoelstra
# (281, 23)
# 4034
# spragbr01 Bruce Spraggins
# (71, 25)
# 4035
# sprewla01 Latrell Sprewell
# (985, 30)
# 4036
# sprigla01 Larry Spriggs
# (199, 30)
# 4037
# sprinji01 Jim Springer
# (2, 22)
# 4038
# spruiji01 Jim Spruill
# (1, 22)
# 4039
# df shape (12453, 31)
# stackry01 Ryan Stack
# (88, 29)
# 4040
# stackje01 Jerry Stackhouse
# (1331, 31)
# 4041
# stacoke01 Kevin Stacom
# (373, 29)
# 4042
# stagger01 Erv Staggs
# (50, 25)
# 4043
# stallbu01 Bud Stallworth
# (312, 24)
# 4044
# stallda01 Dave Stallworth
# (562, 25)
# 4045
# stanced01 Ed Stanczak
# (75, 23)
# 4046
# stanste01 Terence Stansbury
# (192, 29)
# 4047
# starkjo01 John Starks
# (1003, 30)
# 4048
# starrke01 Keith Starr
# (17, 24)
# 4049
# df shape (16456, 31)
# stausni01 Nik Stauskas
# (406, 29)
# 4050
# stavela01 Larry Staverman
# (264, 23)
# 4051
# steella01 Larry Steele
# (637, 29)
# 4052
# steigma01 Matt Steigenga
# (4, 29)
# 4053
# stepavl01 Vladimir Stepania
# (405, 29)
# 4054
# stephdj01 D.J. Stephens
# (40, 29)
# 4055
# stephev01 Everette Stephens
# (38, 29)
# 4056
# stephja01 Jack Stephens
# (71, 23)
# 4057
# stephjo01 Joe Stephens
# (35, 29)
# 4058
# stephla01 Lance Stephenson
# (720, 30)
# 4059
# df shape (19076, 31)
# stephal01 Alex Stepheson
# (16, 29)
# 4060
# steppbr01 Brook Steppe
# (237, 30)
# 4061
# steveba01 Barry Stevens
# (2, 29)
# 4062
# stevewa01 Wayne Stevens
# (8, 22)
# 4063
# stevede01 DeShawn Stevenson
# (1070, 31)
# 4064
# stewade01 Dennis Stewart
# (2, 25)
# 4065
# stewake01 Kebu Stewart
# (31, 29)
# 4066
# stewala01 Larry Stewart
# (281, 30)
# 4067
# stewami01 Michael Stewart
# (478, 30)
# 4068
# stewano01 Norm Stewart
# (5, 22)
# 4069
# df shape (21206, 31)
# stiemgr01 Greg Stiemsma
# (333, 31)
# 4070
# stipast01 Steve Stipanovich
# (407, 30)
# 4071
# stithbr01 Bryant Stith
# (681, 30)
# 4072
# stithsa01 Sam Stith
# (30, 22)
# 4073
# stithto01 Tom Stith
# (25, 22)
# 4074
# stivral01 Alex Stivrins
# (22, 29)
# 4075
# stockda01 David Stockton
# (0, 31)
# 4076
# stockjo01 John Stockton*
# (1686, 30)
# 4077
# stojape01 Peja Stojaković
# (1123, 30)
# 4078
# stokeed01 Ed Stokes
# (10, 29)
# 4079
# df shape (25523, 31)
# stokegr01 Greg Stokes
# (42, 30)
# 4080
# stokeja01 Jarnell Stokes
# (146, 29)
# 4081
# stokema01 Maurice Stokes*
# (203, 23)
# 4082
# stolkar01 Art Stolkey
# (23, 22)
# 4083
# stollra01 Randy Stoll
# (24, 25)
# 4084
# stonedi01 Diamond Stone
# (82, 29)
# 4085
# stonege01 George Stone
# (293, 27)
# 4086
# stoneju01 Julyan Stone
# (327, 31)
# 4087
# storeaw01 Awvee Storey
# (175, 29)
# 4088
# stoudda01 Damon Stoudamire
# (1062, 30)
# 4089
# df shape (27900, 31)
# stoudsa01 Salim Stoudamire
# (249, 30)
# 4090
# stoudam01 Amar'e Stoudemire
# (1201, 31)
# 4091
# stovapa01 Paul Stovall
# (38, 27)
# 4092
# strawdj01 D.J. Strawberry
# (83, 30)
# 4093
# strawjo01 Joe Strawder
# (238, 23)
# 4094
# stricbi01 Bill Stricker
# (1, 22)
# 4095
# stricer01 Erick Strickland
# (632, 30)
# 4096
# stricma01 Mark Strickland
# (448, 30)
# 4097
# stricro02 Rod Strickland
# (1201, 30)
# 4098
# stricro01 Roger Strickland
# (1, 22)
# 4099
# df shape (31992, 31)
# stroejo01 John Stroeder
# (47, 30)
# 4100
# stronde01 Derek Strong
# (543, 30)
# 4101
# strotla01 Lamont Strothers
# (13, 29)
# 4102
# stroujo01 John Stroud
# (9, 28)
# 4103
# stroure01 Red Stroud
# (7, 25)
# 4104
# strusma01 Max Strus
# (65, 29)
# 4105
# stuckro01 Rodney Stuckey
# (823, 30)
# 4106
# stumpge01 Gene Stump
# (148, 23)
# 4107
# stutzst01 Stan Stutz
# (173, 23)
# 4108
# suitega01 Gary Suiter
# (28, 22)
# 4109
# df shape (33848, 31)
# sullija01 Jared Sullinger
# (400, 31)
# 4110
# summeda01 DaJuan Summers
# (205, 29)
# 4111
# sumneed01 Edmond Sumner
# (233, 31)
# 4112
# sumptba01 Barry Sumpter
# (1, 29)
# 4113
# sundedo01 Don Sunderlage
# (112, 22)
# 4114
# sundobr01 Bruno Šundov
# (353, 30)
# 4115
# sundvjo01 Jon Sundvold
# (512, 30)
# 4116
# surabo01 Bob Sura
# (707, 30)
# 4117
# surhodi01 Dick Surhoff
# (57, 23)
# 4118
# sutorge01 George Sutor
# (80, 26)
# 4119
# df shape (36508, 31)
# suttlda01 Dane Suttle
# (46, 29)
# 4120
# suttogr01 Greg Sutton
# (173, 30)
# 4121
# swageke01 Keith Swagerty
# (80, 25)
# 4122
# swainbe01 Bennie Swain
# (58, 23)
# 4123
# swanica01 Caleb Swanigan
# (231, 31)
# 4124
# swansno01 Norm Swanson
# (64, 23)
# 4125
# swartda01 Dan Swartz
# (40, 23)
# 4126
# sweetmi01 Mike Sweetney
# (317, 30)
# 4127
# swiftro01 Robert Swift
# (373, 29)
# 4128
# swiftsk01 Skeeter Swift
# (283, 27)
# 4129
# df shape (38173, 31)
# swiftst01 Stromile Swift
# (741, 30)
# 4130
# swinsaa01 Aaron Swinson
# (9, 29)
# 4131
# sypa01 Pape Sy
# (86, 30)
# 4132
# sydnobu01 Buck Sydnor
# (15, 22)
# 4133
# sykesla01 Larry Sykes
# (1, 29)
# 4134
# szabobr01 Brett Szabo
# (81, 29)
# 4135
# szczewa02 Wally Szczerbiak
# (792, 30)
# 4136
# szczewa01 Walt Szczerbiak
# (51, 26)
# 4137
# tabakza01 Žan Tabak
# (337, 30)
# 4138
# tabusyu01 Yuta Tabuse
# (7, 29)
# 4139
# df shape (40293, 31)
# taftch01 Chris Taft
# (82, 29)
# 4140
# tanensi01 Sid Tanenbaum
# (76, 23)
# 4141
# tarladr01 Dragan Tarlać
# (67, 29)
# 4142
# tarplro01 Roy Tarpley
# (304, 30)
# 4143
# tartle01 Levern Tart
# (283, 26)
# 4144
# tatumea01 Earl Tatum
# (260, 29)
# 4145
# tatumja01 Jayson Tatum
# (256, 30)
# 4146
# tavarwa01 Edy Tavares
# (85, 29)
# 4147
# tayloan01 Anthony Taylor
# (21, 29)
# 4148
# taylobr01 Brian Taylor
# (638, 29)
# 4149
# df shape (42365, 31)
# taylodo01 Donell Taylor
# (166, 30)
# 4150
# taylofa01 Fatty Taylor
# (694, 28)
# 4151
# taylofr01 Fred Taylor
# (88, 22)
# 4152
# taylois01 Isaiah Taylor
# (104, 31)
# 4153
# tayloja01 Jay Taylor
# (17, 29)
# 4154
# tayloje01 Jeff Taylor
# (56, 29)
# 4155
# tayloje03 Jeffery Taylor
# (240, 29)
# 4156
# tayloje02 Jermaine Taylor
# (167, 29)
# 4157
# taylojo01 Johnny Taylor
# (89, 29)
# 4158
# taylole01 Leonard Taylor
# (10, 29)
# 4159
# df shape (43996, 31)
# tayloma01 Maurice Taylor
# (638, 30)
# 4160
# taylomi01 Mike Taylor
# (82, 29)
# 4161
# taylool01 Oliver Taylor
# (291, 28)
# 4162
# tayloro01 Ronald Taylor
# (76, 27)
# 4163
# tayloty01 Tyshawn Taylor
# (129, 31)
# 4164
# taylovi01 Vince Taylor
# (31, 28)
# 4165
# teaglte01 Terry Teagle
# (732, 30)
# 4166
# teaguje01 Jeff Teague
# (941, 30)
# 4167
# teaguma01 Marquis Teague
# (195, 31)
# 4168
# teletmi01 Mirza Teletović
# (506, 31)
# 4169
# df shape (47617, 31)
# telfase01 Sebastian Telfair
# (738, 29)
# 4170
# templco01 Collis Temple
# (24, 27)
# 4171
# templga01 Garrett Temple
# (719, 31)
# 4172
# teodomi01 Miloš Teodosić
# (137, 29)
# 4173
# terreir01 Ira Terrell
# (128, 28)
# 4174
# terreja01 Jared Terrell
# (82, 29)
# 4175
# terryca01 Carlos Terry
# (97, 29)
# 4176
# terrych01 Chuck Terry
# (296, 28)
# 4177
# terrycl01 Claude Terry
# (377, 29)
# 4178
# terryem01 Emanuel Terry
# (9, 29)
# 4179
# df shape (50224, 31)
# terryja01 Jason Terry
# (1666, 31)
# 4180
# thabeha01 Hasheem Thabeet
# (424, 31)
# 4181
# thackto01 Tom Thacker
# (374, 26)
# 4182
# thearfl01 Floyd Theard
# (23, 25)
# 4183
# theisda01 Daniel Theis
# (256, 31)
# 4184
# theusre01 Reggie Theus
# (1043, 30)
# 4185
# thibepe01 Peter Thibeaux
# (93, 29)
# 4186
# thiebbi01 Bill Thieben
# (87, 23)
# 4187
# thigpju01 Justus Thigpen
# (22, 27)
# 4188
# thirdda01 David Thirdkill
# (197, 30)
# 4189
# df shape (54409, 31)
# thomaad01 Adonis Thomas
# (14, 29)
# 4190
# thomabi01 Billy Thomas
# (96, 30)
# 4191
# thomaca01 Carl Thomas
# (99, 30)
# 4192
# thomach01 Charles Thomas
# (36, 29)
# 4193
# thomaet01 Etan Thomas
# (780, 30)
# 4194
# thomair01 Irving Thomas
# (26, 30)
# 4195
# thomais02 Isaiah Thomas
# (735, 31)
# 4196
# thomais01 Isiah Thomas*
# (1090, 30)
# 4197
# thomaja01 Jamel Thomas
# (17, 29)
# 4198
# thomaja02 James Thomas
# (43, 29)
# 4199
# df shape (57345, 31)
# thomaji01 Jim Thomas
# (161, 29)
# 4200
# thomajo01 Joe Thomas
# (39, 22)
# 4201
# thomajo02 John Thomas
# (289, 30)
# 4202
# thomake01 Kenny Thomas
# (893, 30)
# 4203
# thomakh01 Khyri Thomas
# (152, 31)
# 4204
# thomaku01 Kurt Thomas
# (1387, 30)
# 4205
# thomala01 Lance Thomas
# (540, 29)
# 4206
# thomama01 Malcolm Thomas
# (140, 31)
# 4207
# thomama02 Matt Thomas
# (64, 29)
# 4208
# thomaro01 Ronald Thomas
# (313, 28)
# 4209
# df shape (61323, 31)
# thomate01 Terry Thomas
# (27, 25)
# 4210
# thomati01 Tim Thomas
# (1078, 30)
# 4211
# thomaty01 Tyrus Thomas
# (585, 30)
# 4212
# thomawi01 Willis Thomas
# (59, 25)
# 4213
# thomptr02 Trey Thompkins
# (66, 29)
# 4214
# thompbe01 Bernard Thompson
# (206, 30)
# 4215
# thompbi01 Billy Thompson
# (303, 30)
# 4216
# thompbr01 Brooks Thompson
# (216, 30)
# 4217
# thompco01 Corny Thompson
# (44, 28)
# 4218
# thompda01 David Thompson*
# (632, 29)
# 4219
# df shape (64539, 31)
# thompdi01 Dijon Thompson
# (93, 29)
# 4220
# thompge01 George Thompson
# (436, 27)
# 4221
# thompho01 Hollis Thompson
# (289, 29)
# 4222
# thompja01 Jack Thompson
# (2, 25)
# 4223
# thompja02 Jason Thompson
# (636, 31)
# 4224
# thompjo01 John Thompson*
# (79, 23)
# 4225
# thompke01 Kevin Thompson
# (14, 29)
# 4226
# thompkl01 Klay Thompson
# (764, 31)
# 4227
# thompla01 LaSalle Thompson
# (1061, 30)
# 4228
# thompmy01 Mychal Thompson
# (1039, 30)
# 4229
# df shape (68952, 31)
# thompmy02 Mychel Thompson
# (22, 29)
# 4230
# thomppa01 Paul Thompson
# (157, 30)
# 4231
# thompst01 Stephen Thompson
# (19, 29)
# 4232
# thomptr01 Tristan Thompson
# (786, 31)
# 4233
# thoresk01 Skip Thoren
# (185, 26)
# 4234
# thornro01 Rod Thorn*
# (483, 23)
# 4235
# thornal01 Al Thornton
# (330, 29)
# 4236
# thornbo01 Bob Thornton
# (299, 30)
# 4237
# thornda01 Dallas Thornton
# (52, 26)
# 4238
# thornma01 Marcus Thornton
# (611, 31)
# 4239
# df shape (71896, 31)
# thornsi01 Sindarius Thornwell
# (170, 31)
# 4240
# thorpot01 Otis Thorpe
# (1372, 30)
# 4241
# threase01 Sedale Threatt
# (1026, 30)
# 4242
# thurmna01 Nate Thurmond*
# (1045, 25)
# 4243
# thursme01 Mel Thurston
# (14, 22)
# 4244
# thybuma01 Matisse Thybulle
# (65, 29)
# 4245
# tidriha01 Hal Tidrick
# (64, 23)
# 4246
# tiemada01 Dan Tieman
# (29, 22)
# 4247
# tillida01 Darren Tillis
# (124, 28)
# 4248
# tinglja01 Jack Tingle
# (38, 22)
# 4249
# df shape (75843, 31)
# tinslge01 George Tinsley
# (145, 27)
# 4250
# tinslja01 Jamaal Tinsley
# (914, 30)
# 4251
# tisdawa01 Wayman Tisdale
# (876, 30)
# 4252
# tobeymi01 Mike Tobey
# (7, 29)
# 4253
# todormi01 Mike Todorovich
# (134, 23)
# 4254
# tolbera01 Ray Tolbert
# (266, 30)
# 4255
# tolbeto01 Tom Tolbert
# (312, 30)
# 4256
# tollian01 Anthony Tolliver
# (895, 31)
# 4257
# tolsode01 Dean Tolson
# (79, 28)
# 4258
# tomjaru01 Rudy Tomjanovich
# (805, 29)
# 4259
# df shape (80276, 31)
# toneyan01 Andrew Toney
# (540, 30)
# 4260
# toneyse01 Sedric Toney
# (115, 30)
# 4261
# tonkoan01 Andy Tonkovich
# (12, 22)
# 4262
# toolsan01 Andy Toolson
# (60, 30)
# 4263
# toomaja01 Jack Toomay
# (129, 23)
# 4264
# toonebe01 Bernard Toone
# (23, 29)
# 4265
# torgoir01 Irv Torgoff
# (155, 23)
# 4266
# tormobu01 Gene Tormohlen
# (296, 23)
# 4267
# torreos01 Óscar Torres
# (105, 29)
# 4268
# toscaju01 Juan Toscano-Anderson
# (13, 29)
# 4269
# df shape (81724, 31)
# toshebi01 Bill Tosheff
# (207, 23)
# 4270
# toughbo01 Bob Tough
# (80, 22)
# 4271
# toupaax01 Axel Toupane
# (27, 29)
# 4272
# towemo01 Monte Towe
# (122, 28)
# 4273
# towerke01 Keith Tower
# (53, 29)
# 4274
# towerbl01 Blackie Towery
# (128, 22)
# 4275
# towneli01 Linton Townes
# (68, 30)
# 4276
# townska01 Karl-Anthony Towns
# (397, 30)
# 4277
# townsra01 Raymond Townsend
# (151, 28)
# 4278
# trappge01 George Trapp
# (410, 25)
# 4279
# df shape (83367, 31)
# trappjo01 John Trapp
# (293, 28)
# 4280
# traylro01 Robert Traylor
# (546, 30)
# 4281
# trentga01 Gary Trent
# (598, 30)
# 4282
# trentga02 Gary Trent
# (148, 29)
# 4283
# trepaje01 Jeff Trepagnier
# (58, 29)
# 4284
# tresvjo01 John Tresvant
# (599, 23)
# 4285
# trieral01 Allonzo Trier
# (148, 29)
# 4286
# triptdi01 Dick Triptow
# (58, 22)
# 4287
# tripuke01 Kelly Tripucka
# (732, 30)
# 4288
# truitan01 Ansley Truitt
# (15, 27)
# 4289
# df shape (86562, 31)
# trybace01 Cezary Trybański
# (91, 29)
# 4290
# tsakaja01 Jake Tsakalidis
# (532, 30)
# 4291
# tschojo01 John Tschogl
# (116, 25)
# 4292
# tsiorlo01 Lou Tsioropoulos
# (158, 23)
# 4293
# tskitni01 Nikoloz Tskitishvili
# (313, 30)
# 4294
# tuckeal01 Al Tucker
# (350, 27)
# 4295
# tuckeal02 Alando Tucker
# (234, 29)
# 4296
# tuckean01 Anthony Tucker
# (62, 29)
# 4297
# tuckeji01 Jim Tucker
# (114, 23)
# 4298
# tuckepj01 P.J. Tucker
# (740, 30)
# 4299
# df shape (89272, 31)
# tuckera01 Rayjon Tucker
# (34, 29)
# 4300
# tucketr01 Trent Tucker
# (822, 30)
# 4301
# turiaro01 Ronny Turiaf
# (757, 31)
# 4302
# turkcmi01 Mirsad Türkcan
# (78, 30)
# 4303
# turkohe01 Hedo Türkoğlu
# (1306, 31)
# 4304
# turnean01 Andre Turner
# (170, 30)
# 4305
# turnebi01 Bill Turner
# (313, 23)
# 4306
# turneel01 Elston Turner
# (548, 30)
# 4307
# turneev01 Evan Turner
# (860, 31)
# 4308
# turnega01 Gary Turner
# (2, 25)
# 4309
# df shape (94162, 31)
# turnehe02 Henry Turner
# (66, 29)
# 4310
# turnehe01 Herschell Turner
# (40, 25)
# 4311
# turneja01 Jack Turner
# (67, 23)
# 4312
# turneja02 Jack Turner
# (41, 22)
# 4313
# turneje01 Jeff Turner
# (636, 30)
# 4314
# turnejo01 John Turner
# (42, 29)
# 4315
# turnemy01 Myles Turner
# (415, 30)
# 4316
# turnewa01 Wayne Turner
# (4, 29)
# 4317
# turpime01 Melvin Turpin
# (372, 30)
# 4318
# twardda01 Dave Twardzik
# (568, 29)
# 4319
# df shape (96413, 31)
# twymaja01 Jack Twyman*
# (856, 23)
# 4320
# tylerbj01 B.J. Tyler
# (55, 29)
# 4321
# tylerje01 Jeremy Tyler
# (179, 29)
# 4322
# tylerte01 Terry Tyler
# (888, 30)
# 4323
# tyrach01 Charlie Tyra
# (350, 23)
# 4324
# ubileed01 Edwin Ubiles
# (6, 29)
# 4325
# udohek01 Ekpe Udoh
# (589, 31)
# 4326
# udokaim01 Ime Udoka
# (379, 30)
# 4327
# udrihbe01 Beno Udrih
# (1079, 31)
# 4328
# ukicro01 Roko Ukić
# (113, 29)
# 4329
# df shape (100907, 31)
# ulisty01 Tyler Ulis
# (198, 29)
# 4330
# unselwe01 Wes Unseld*
# (1103, 29)
# 4331
# uplinha01 Hal Uplinger
# (23, 22)
# 4332
# upshake01 Kelvin Upshaw
# (123, 30)
# 4333
# uthofja01 Jarrod Uthoff
# (25, 29)
# 4334
# uzohbe01 Ben Uzoh
# (103, 29)
# 4335
# vacenst01 Stephen Vacendak
# (96, 26)
# 4336
# valanjo01 Jonas Valančiūnas
# (690, 31)
# 4337
# valenda01 Darnell Valentine
# (646, 30)
# 4338
# valende01 Denzel Valentine
# (317, 31)
# 4339
# df shape (104231, 31)
# valenro01 Ronnie Valentine
# (24, 28)
# 4340
# vallejo01 John Vallely
# (99, 22)
# 4341
# vanardi01 Dick Van Arsdale
# (955, 25)
# 4342
# vanarto01 Tom Van Arsdale
# (929, 24)
# 4343
# vanexni01 Nick Van Exel
# (1024, 30)
# 4344
# vanhoke01 Keith Van Horn
# (718, 30)
# 4345
# vanlino01 Norm Van Lier
# (784, 28)
# 4346
# vanzade01 Dennis Van Zant
# (1, 27)
# 4347
# vanvlfr01 Fred VanVleet
# (354, 31)
# 4348
# vancege01 Gene Vance
# (184, 23)
# 4349
# df shape (109303, 31)
# vandelo01 Logan Vander Velden
# (15, 29)
# 4350
# vandeja01 Jarred Vanderbilt
# (148, 31)
# 4351
# vandeer01 Ernie Vandeweghe
# (268, 23)
# 4352
# vandeki01 Kiki Vandeweghe
# (878, 30)
# 4353
# vanosni01 Nick Vanos
# (68, 29)
# 4354
# vanteda01 David Vanterpool
# (22, 29)
# 4355
# vardara01 Ratko Varda
# walkean01 Andy Walker
# (40, 24)
# 4408
# walkean02 Antoine Walker
# (1014, 30)
# 4409
# df shape (127920, 31)
# walkebr01 Brady Walker
# (222, 22)
# 4410
# walkech01 Chet Walker*
# (1137, 25)
# 4411
# walkeda01 Darrell Walker
# (754, 30)
# 4412
# walkefo01 Foots Walker
# (22, 28)
# 4413
# walkebi01 Henry Walker
# (8, 28)
# 4414
# walkeho01 Horace Walker
# (64, 22)
# 4415
# walkeji01 Jimmy Walker
# (710, 25)
# 4416
# walkeke02 Kemba Walker
# (714, 30)
# 4417
# walkeke01 Kenny Walker
# (474, 30)
# 4418
# walkelo01 Lonnie Walker
# (152, 31)
# 4419
# df shape (132177, 31)
# walkeph01 Phil Walker
# (40, 28)
# 4420
# walkesa01 Samaki Walker
# (654, 30)
# 4421
# walkewa01 Wally Walker
# (628, 29)
# 4422
# walljo01 John Wall
# (762, 31)
# 4423
# wallabe01 Ben Wallace
# (1381, 30)
# 4424
# wallage01 Gerald Wallace
# (1155, 31)
# 4425
# wallajo01 John Wallace
# (531, 30)
# 4426
# wallara01 Rasheed Wallace
# (1408, 30)
# 4427
# wallare01 Red Wallace
# (61, 22)
# 4428
# wallaty01 Tyrone Wallace
# (159, 31)
# 4429
# df shape (138956, 31)
# walledw01 Dwight Waller
# (17, 26)
# 4430
# walleja01 Jamie Waller
# (9, 29)
# 4431
# princta02 Taurean Waller-Prince
# (316, 30)
# 4432
# walshji01 Jim Walsh
# (10, 22)
# 4433
# walshma01 Matt Walsh
# both dfs are None
# 4434
# waltere01 Rex Walters
# (412, 30)
# 4435
# walthpa01 Paul Walther
# (392, 23)
# 4436
# walthis01 Isaac Walthour
# (4, 22)
# 4437
# waltobi01 Bill Walton*
# (517, 30)
# 4438
# waltode01 Derrick Walton
# (137, 29)
# 4439
# df shape (140770, 31)
# waltoll01 Lloyd Walton
# (359, 29)
# 4440
# waltolu01 Luke Walton
# (893, 30)
# 4441
# wanambr01 Brad Wanamaker
# (146, 31)
# 4442
# wanzebo01 Bobby Wanzer*
# (608, 23)
# 4443
# warbipe01 Perry Warbington
# (5, 24)
# 4444
# wardch01 Charlie Ward
# (751, 30)
# 4445
# wardge01 Gerry Ward
# (182, 23)
# 4446
# wardhe01 Henry Ward
# (94, 28)
# 4447
# wareca01 Casper Ware
# (12, 29)
# 4448
# wareji01 Jim Ware
# (66, 26)
# 4449
# df shape (143886, 31)
# warlebe01 Ben Warley
# (449, 26)
# 4450
# warlibo01 Bob Warlick
# (198, 26)
# 4451
# warneco01 Cornell Warner
# (466, 25)
# 4452
# warneja01 Jameel Warney
# (5, 29)
# 4453
# warrebo01 Bob Warren
# (521, 28)
# 4454
# warrejo01 John Warren
# (303, 25)
# 4455
# warretj01 T.J. Warren
# (475, 29)
# 4456
# warrewi01 Willie Warren
# (82, 29)
# 4457
# warribr01 Bryan Warrick
# (169, 29)
# 4458
# warriha01 Hakim Warrick
# (612, 29)
# 4459
# df shape (147166, 31)
# washbch01 Chris Washburn
# (78, 30)
# 4460
# washbju01 Julian Washburn
# (39, 29)
# 4461
# washibo01 Bobby Washington
# (117, 25)
# 4462
# washida01 Darius Washington
# (28, 29)
# 4463
# washido01 Donald Washington
# (54, 28)
# 4464
# washidu01 Duane Washington
# (19, 29)
# 4465
# washier01 Eric Washington
# (132, 29)
# 4466
# washiji01 Jim Washington
# (816, 25)
# 4467
# washike01 Kermit Washington
# (516, 30)
# 4468
# washipj01 P.J. Washington
# (65, 29)
# 4469
# df shape (149030, 31)
# washipe01 Pearl Washington
# (194, 29)
# 4470
# washiri01 Richard Washington
# (362, 29)
# 4471
# washist01 Stan Washington
# (1, 24)
# 4472
# washitr01 Trooper Washington
# (492, 28)
# 4473
# washiwi01 Wilson Washington
# (100, 27)
# 4474
# watanyu01 Yuta Watanabe
# (147, 29)
# 4475
# watertr01 Tremont Waters
# (64, 29)
# 4476
# watkida01 Darryl Watkins
# (25, 29)
# 4477
# watsobo01 Bobby Watson
# (43, 22)
# 4478
# watsocj01 C.J. Watson
# (817, 30)
# 4479
# df shape (151275, 31)
# watsoea01 Earl Watson
# (1059, 31)
# 4480
# watsoja01 Jamie Watson
# (136, 30)
# 4481
# watsopa01 Paul Watson
# (30, 29)
# 4482
# wattsro01 Ron Watts
# (29, 23)
# 4483
# wattssa01 Samuel Watts
# (52, 25)
# 4484
# wattssl01 Slick Watts
# (454, 28)
# 4485
# waynsma01 Maalik Wayns
# (96, 29)
# 4486
# wearda01 David Wear
# (5, 29)
# 4487
# weartr01 Travis Wear
# (103, 29)
# 4488
# weathcl01 Clarence Weatherspoon
# (1008, 30)
# 4489
# df shape (154247, 31)
# weathni01 Nick Weatherspoon
# (484, 29)
# 4490
# weathqu01 Quinndary Weatherspoon
# (63, 29)
# 4491
# weaveky01 Kyle Weaver
# (170, 30)
# 4492
# webbja01 James Webb
# (38, 29)
# 4493
# webbje01 Jeff Webb
# (74, 23)
# 4494
# webbma01 Marcus Webb
# (9, 29)
# 4495
# webbsp01 Spud Webb
# (853, 30)
# 4496
# webbech01 Chris Webber
# (1049, 30)
# 4497
# weberbr01 Briante Weber
# (81, 31)
# 4498
# weberja01 Jake Weber
# (46, 22)
# 4499
# df shape (157114, 31)
# webstel01 Elnardo Webster
# (19, 26)
# 4500
# webstje01 Jeff Webster
# (11, 29)
# 4501
# webstma02 Martell Webster
# (831, 31)
# 4502
# webstma01 Marvin Webster
# (678, 30)
# 4503
# wedmasc01 Scott Wedman
# (991, 30)
# 4504
# weemsso01 Sonny Weems
# (318, 29)
# 4505
# wehrdi01 Dick Wehr
# (8, 22)
# 4506
# weidnbr01 Brant Weidner
# (8, 28)
# 4507
# weissbo01 Bob Weiss
# (836, 25)
# 4508
# weitzri01 Rick Weitzman
# (24, 23)
# 4509
# df shape (160838, 31)
# wellsbo01 Bonzi Wells
# (792, 30)
# 4510
# wellsbu01 Bubba Wells
# (76, 29)
# 4511
# wellsow01 Owen Wells
# (33, 25)
# 4512
# wellsra01 Ralph Wells
# (3, 22)
# 4513
# welpch01 Chris Welp
# (112, 30)
# 4514
# welscji01 Jiří Welsch
# (338, 30)
# 4515
# welshth01 Thomas Welsh
# (82, 29)
# 4516
# wennibi01 Bill Wennington
# (836, 30)
# 4517
# wenstma01 Matt Wenstrom
# (11, 29)
# 4518
# werdaro01 Robert Werdann
# (54, 29)
# 4519
# df shape (163175, 31)
# wertira01 Ray Wertis
# (70, 23)
# 4520
# wesleda01 David Wesley
# (1086, 30)
# 4521
# weslewa01 Walt Wesley
# (596, 25)
# 4522
# westda01 David West
# (1293, 31)
# 4523
# westde01 Delonte West
# (657, 30)
# 4524
# westdo01 Doug West
# (744, 30)
# 4525
# westje01 Jerry West*
# (1085, 25)
# 4526
# westma02 Mario West
# (241, 30)
# 4527
# westma01 Mark West
# (1261, 30)
# 4528
# westro01 Roland West
# (4, 22)
# 4529
# df shape (170212, 31)
# westbde01 Dexter Westbrook
# (13, 25)
# 4530
# westbru01 Russell Westbrook
# (1057, 31)
# 4531
# westppa01 Paul Westphal*
# (930, 29)
# 4532
# wetzejo01 John Wetzel
# (361, 25)
# 4533
# whalero01 Robert Whaley
# (82, 29)
# 4534
# whatlen01 Ennis Whatley
# (420, 30)
# 4535
# wheatde01 DeJuan Wheat
# (115, 30)
# 4536
# wheelcl01 Clinton Wheeler
# (87, 29)
# 4537
# wheelty01 Tyson Wheeler
# (9, 29)
# 4538
# whitask01 Skippy Whitaker
# (3, 22)
# 4539
# df shape (173289, 31)
# whitean01 Andrew White
# (40, 29)
# 4540
# whiteco01 Coby White
# (65, 29)
# 4541
# whitedj01 D.J. White
# (358, 31)
# 4542
# whitede01 Derrick White
# (239, 31)
# 4543
# whiteer01 Eric White
# (55, 29)
# 4544
# whitehe01 Herb White
# (37, 22)
# 4545
# whitehu01 Hubie White
# (118, 25)
# 4546
# whiteja01 Jahidi White
# (420, 29)
# 4547
# whiteja02 James White
# (200, 31)
# 4548
# whitejo01 Jo Jo White*
# (915, 29)
# 4549
# df shape (175736, 31)
# whiteok01 Okaro White
# (118, 29)
# 4550
# whitera01 Randy White
# (282, 30)
# 4551
# whitero02 Rodney White
# (317, 30)
# 4552
# whitero01 Rory White
# (327, 30)
# 4553
# whitero03 Royce White
# (10, 29)
# 4554
# whiteru01 Rudy White
# (125, 29)
# 4555
# whiteto01 Tony White
# (49, 29)
# 4556
# whitewi01 Willie White
# (96, 30)
# 4557
# whiteis01 Isaiah Whitehead
# (164, 29)
# 4558
# whiteje01 Jerome Whitehead
# (679, 30)
# 4559
# df shape (177903, 31)
# whitedo01 Donald Whiteside
# (35, 29)
# 4560
# whiteha01 Hassan Whiteside
# (628, 31)
# 4561
# whitfdw01 Dwayne Whitfield
# (8, 29)
# 4562
# whitnch01 Chris Whitney
# (630, 30)
# 4563
# whitnha01 Hank Whitney
# (149, 26)
# 4564
# whitnha02 Hawkeye Whitney
# (70, 28)
# 4565
# whittsh01 Shayne Whittington
# (164, 29)
# 4566
# wickssi01 Sidney Wicks
# (760, 29)
# 4567
# widbyro01 Ron Widby
# (0, 26)
# 4568
# wiermu01 Murray Wier
# (59, 23)
# 4569
# df shape (180406, 31)
# (887, 30)
# 4732
# workmha01 Haywoode Workman
# (436, 30)
# 4733
# workmma01 Mark Workman
# (76, 22)
# 4734
# workmto01 Tom Workman
# (97, 26)
# 4735
# artesro01 Metta World Peace
# (86, 29)
# 4736
# worslwi01 Willie Worsley
# (24, 25)
# 4737
# worthsa01 Sam Worthen
# (70, 29)
# 4738
# worthja01 James Worthy*
# (1069, 30)
# 4739
# df shape (237546, 31)
# wrighan01 Antoine Wright
# (454, 30)
# 4740
# wrighbr02 Bracey Wright
# (162, 29)
# 4741
# wrighbr01 Brad Wright
# (16, 29)
# 4742
# wrighbr03 Brandan Wright
# (894, 31)
# 4743
# wrighch01 Chris Wright
# (77, 29)
# 4744
# wrighch02 Chris Wright
# (6, 29)
# 4745
# wrighde01 Delon Wright
# (435, 31)
# 4746
# wrighdo01 Dorell Wright
# (846, 31)
# 4747
# wrighho02 Howard Wright
# (19, 29)
# 4748
# wrighho01 Howie Wright
# (53, 27)
# 4749
# df shape (240508, 31)
# wrighjo01 Joby Wright
# (103, 27)
# 4750
# wrighju01 Julian Wright
# (343, 30)
# 4751
# wrighla01 Larry Wright
# (392, 29)
# 4752
# wrighle01 Leroy Wright
# (41, 26)
# 4753
# wrighlo01 Lonnie Wright
# (360, 27)
# 4754
# wrighlo02 Lorenzen Wright
# (989, 30)
# 4755
# wrighlu01 Luther Wright
# (15, 29)
# 4756
# wrighsh01 Sharone Wright
# (226, 29)
# 4757
# wrighju02 Justin Wright-Foreman
# (64, 29)
# 4758
# wroteto01 Tony Wroten
# (291, 31)
# 4759
# df shape (243332, 31)
# wuycide01 Dennis Wuycik
# (171, 28)
# 4760
# wyndeaj01 A.J. Wynder
# (6, 29)
# 4761
# yabusgu01 Guerschon Yabusele
# (192, 31)
# 4762
# yarbrvi01 Vincent Yarbrough
# (61, 29)
# 4763
# yardlge01 George Yardley*
# (518, 23)
# 4764
# yatesba01 Barry Yates
# (24, 22)
# 4765
# yateswa01 Wayne Yates
# (38, 23)
# 4766
# yelvech01 Charlie Yelverton
# (68, 22)
# 4767
# yonakri01 Rich Yonakor
# (0, 29)
# 4768
# youngda01 Danny Young
# (627, 30)
# 4769
# df shape (245037, 31)
# youngja01 James Young
# (308, 31)
# 4770
# youngjo01 Joe Young
# (264, 31)
# 4771
# youngko01 Korleone Young
# (8, 29)
# 4772
# youngmi01 Michael Young
# (49, 30)
# 4773
# youngni01 Nick Young
# (932, 31)
# 4774
# youngpe01 Perry Young
# (9, 29)
# 4775
# youngsa01 Sam Young
# (333, 31)
# 4776
# youngth01 Thaddeus Young
# (1085, 30)
# 4777
# youngti01 Tim Young
# (50, 29)
# 4778
# youngtr01 Trae Young
# (149, 29)
# 4779
# df shape (248224, 31)
# yuesu01 Sun Yue
# (82, 29)
# 4780
# zasloma01 Max Zaslofsky
# (603, 23)
# 4781
# zawolze01 Zeke Zawoluk
# (179, 23)
# 4782
# zelleco01 Cody Zeller
# (568, 30)
# 4783
# zelleda01 Dave Zeller
# (48, 23)
# 4784
# zellega01 Gary Zeller
# (95, 27)
# 4785
# zelleha01 Harry Zeller
# (48, 22)
# 4786
# zellelu01 Luke Zeller
# (55, 29)
# 4787
# zellety01 Tyler Zeller
# (538, 31)
# 4788
# zenoto01 Tony Zeno
# (8, 28)
# 4789
# df shape (250448, 31)
# zevenph01 Phil Zevenbergen
# (9, 30)
# 4790
# zhizhwa01 Wang Zhizhi
# (290, 30)
# 4791
# zidekge01 George Zídek
# (194, 29)
# 4792
# zimmede01 Derrick Zimmerman
# (2, 29)
# 4793
# zimmest01 Stephen Zimmerman
# (82, 29)
# 4794
# zipsepa01 Paul Zipser
# (170, 30)
# 4795
# zizican01 Ante Žižić
# (229, 31)
# 4796
# zoetji01 Jim Zoet
# (7, 28)
# 4797
# zopfbi01 Bill Zopf
# (52, 22)
# 4798
# zubaciv01 Ivica Zubac
# (316, 31)
# 4799
# df shape (251799, 31)
# zunicma01 Matt Zunic
# (56, 23)
#
#
# (251855, 31)

# %%
print(game_logs.shape)
# Out:
# (351913, 31)

# %%
print(game_logs.shape)
# Out:
# (329749, 31)

# %%
game_logs.tail()
# Out:
#         Rk   G        DATE     AGE TEAM HOME/AWAY OPPONENT   RESULT GS     MP  \
# 329744  62  48  2020-03-01  30-181  LAL      AWAY      NOP   W (+8)  0  14:36
# 329745  63  49  2020-03-03  30-183  LAL      HOME      PHI  W (+13)  0  12:57
# 329746  64  50  2020-03-06  30-186  LAL      HOME      MIL  W (+10)  0   8:44
# 329747  65  51  2020-03-08  30-188  LAL      AWAY      LAC   W (+9)  0  16:23
# 329748  66  52  2020-03-10  30-190  LAL      HOME      BRK   L (-2)  0  14:41
#
#         ...      INDEX             NAME STL% BLK%  eFG%  TOV%  USG%  \
# 329744  ...  morrima02  Markieff Morris  3.1  0.0  .625   0.0  23.0
# 329745  ...  morrima02  Markieff Morris  0.0  8.2  .000  41.0  16.9
# 329746  ...  morrima02  Markieff Morris  0.0  0.0  .833   0.0  13.3
# 329747  ...  morrima02  Markieff Morris  0.0  5.3  .400  16.7  15.8
# 329748  ...  morrima02  Markieff Morris  3.4  6.5  .000  33.3   9.2
#
#        GAME_SCORE  BPM Unnamed: 24
# 329744        7.3  NaN         NaN
# 329745       -0.7  NaN         NaN
# 329746        3.5  NaN         NaN
# 329747        1.7  NaN         NaN
# 329748        2.2  NaN         NaN
#
# [5 rows x 31 columns]

# %%
|
# Out:
#   File "<ipython-input-16-4b37ef281455>", line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
playoff_game_logs = None

row = df.iloc[0]

player_idx = row['index']
letter = player_idx[0]
player_name = row['Player']
print(letter,player_idx,player_name)

from_yr, to_yr = row[["From","To"]].values

#playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs/"
playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs-advanced/"
webpage = urlopen(playoff_url)
html = BeautifulSoup(webpage)
tables = html.findAll('table')

if len(tables) > 0:
    table = str(html.findAll('table')[-1])
    playoff_game_logs = pd.read_html(table)[0]
    playoff_game_logs["PLAYOFF"] = 'Y'

# %%
playoff_game_logs
