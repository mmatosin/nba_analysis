# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# #### data directories

# %%
currDir = os.getcwd()
rootDir = os.path.abspath(os.path.join(currDir,'..'))

dataDir = os.path.abspath(os.path.join(rootDir,'data'))
rawDataDir = os.path.abspath(os.path.join(dataDir,'raw'))
interimDataDir = os.path.abspath(os.path.join(dataDir,'interim'))
finalDataDir = os.path.abspath(os.path.join(dataDir,'final'))

advDataDir = os.path.abspath(os.path.join(dataDir,'advanced_stats'))
errorLog = os.path.abspath(os.path.join(dataDir,'error_log'))

# %% [markdown]
# #### read player bio data

# %%
file = f"{rawDataDir}/all_NBA_ABA_players.csv"
df = pd.read_csv(file)

print("No of distinct players:",df['index'].nunique())
# Out:
# No of distinct players: 4800

# %%
df.head()
# Out:
#        index                Player  From    To  Pos    Ht     Wt  \
# 0  abdelal01        Alaa Abdelnaby  1991  1995  F-C  6-10  240.0
# 1  abdulza01       Zaid Abdul-Aziz  1969  1978  C-F   6-9  235.0
# 2  abdulka01  Kareem Abdul-Jabbar*  1970  1989    C   7-2  225.0
# 3  abdulma02    Mahmoud Abdul-Rauf  1991  2001    G   6-1  162.0
# 4  abdulta01     Tariq Abdul-Wahad  1998  2003    F   6-6  223.0
#
#          Birth Date                  Colleges
# 0     June 24, 1968                      Duke
# 1     April 7, 1946                Iowa State
# 2    April 16, 1947                      UCLA
# 3     March 9, 1969                       LSU
# 4  November 3, 1974  Michigan, San Jose State

# %% [markdown]
# #### scraping player game logs

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

#### BASIC STATS
# https://www.basketball-reference.com/players/a/abdelal01.html
# https://www.basketball-reference.com/players/a/abdelal01/gamelog/1992
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-playoffs/

#### ADVANCED STATS
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-advanced/1992/
# https://www.basketball-reference.com/players/a/abdelal01/gamelog-playoffs-advanced/

# %%
def get_reg_season_game_logs(player_idx,letter,from_year,to_year):
    reg_season_game_logs = None
    yearly_dfs = []
    
    # SCRAPING REGULAR SEASON GAMES
    
    for year in range(from_year, to_year+1):
        #url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog/{year}"
        url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-advanced/{year}/"
        webpage = urlopen(url)
        html = BeautifulSoup(webpage)
        tables = html.findAll('table')
      
        if len(tables)==0:
            if year > 1976: continue
            else:
                aba_url = url + "/aba/"
                webpage = urlopen(aba_url)
                html = BeautifulSoup(webpage)
                aba_tables = html.findAll('table')

                if len(aba_tables)==0: continue
                else: 
                    table = str(aba_tables[-1])
                    yearly_game_log = pd.read_html(table)[0]
                    yearly_game_log["PLAYOFF"] = 'N'
                    yearly_game_log["LEAGUE"] = 'ABA'

        else:
            table = str(tables[-1])
            yearly_game_log = pd.read_html(table)[0]
            yearly_game_log["PLAYOFF"] = 'N'
            yearly_game_log["LEAGUE"] = 'NBA'

        yearly_dfs.append(yearly_game_log)        

    reg_season_game_logs = pd.concat([x for x in yearly_dfs],ignore_index=True,sort=False)
    reg_season_game_logs["PLAYOFF"] = 'N'
    reg_season_game_logs['SERIES'] = np.nan

    reg_season_game_logs.rename(columns = {'Date': 'DATE', 'Age': 'AGE', 'Tm': 'TEAM', 
                                      'Unnamed: 5': 'HOME/AWAY', 'Opp': 'OPPONENT',
                                      'Unnamed: 7': 'RESULT', 'GmSc': 'GAME_SCORE'}, inplace=True)  
    
    return reg_season_game_logs

# %%
def get_playoff_game_logs(player_idx,letter):
    
    playoff_game_logs = None
    
    #playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs/"
    playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs-advanced/"
    webpage = urlopen(playoff_url)
    html = BeautifulSoup(webpage)
    tables = html.findAll('table')
    
    if len(tables) > 0:
        table = str(html.findAll('table')[-1])
        playoff_game_logs = pd.read_html(table)[0]
        playoff_game_logs["PLAYOFF"] = 'Y'
        playoff_game_logs["AGE"] = np.nan

        playoff_game_logs.rename(columns = {'Date': 'DATE', 'Age': 'AGE', 'Tm': 'TEAM', 'Series':'SERIES',
                                          'Unnamed: 5': 'HOME/AWAY', 'Opp': 'OPPONENT',playoff_game_logs.columns[2]:'DATE',
                                          'Unnamed: 8': 'RESULT', 'GmSc': 'GAME_SCORE'}, inplace=True)
    
    return playoff_game_logs

# %%
def get_career_game_logs(player_data,verbose=True):
    
    logger = f"{errorLog}/log.txt"
    
    # PLAYER DATA
    player_idx = player_data['index']
    letter = player_idx[0]
    player_name = player_data['Player']
    from_yr, to_yr = row[["From","To"]].values

    if verbose:
        print(player_idx,player_name)
    
    # GET REGULAR SEASON GAME LOGS
    try:
        reg_season_game_logs = get_reg_season_game_logs(player_idx,letter,from_yr,to_yr)
    except:
        reg_season_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, error in regular season game logs \n")

    # GET PLAYOFF GAME LOGS
    try:
        playoff_game_logs = get_playoff_game_logs(player_idx,letter)
    except:
        playoff_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, error in playoff game logs \n")
            
        
    try:  
        # CONCATENATING REGULAR SEASON AND PLAYOFF GAMES
        career_game_logs = pd.concat([reg_season_game_logs,playoff_game_logs],ignore_index=True,sort=False)
        career_game_logs['HOME/AWAY'] = career_game_logs['HOME/AWAY'].apply(lambda x: 'AWAY' if x=='@' else 'HOME')

        # FORMAT CAREER GAME LOGS, SORT BY DATE
        career_game_logs['Rk'] = career_game_logs['Rk'].astype(str)
        career_game_logs = career_game_logs[career_game_logs['Rk'].str.isnumeric().values]

        career_game_logs.rename(columns = {'Series':'SERIES'},inplace=True)
        career_game_logs['INDEX'] = player_idx
        career_game_logs['NAME']  = player_name

        career_game_logs.sort_values('DATE',inplace=True)
        career_game_logs.reset_index(drop=True,inplace=True)

    except:
        career_game_logs = None
        with open(logger,"a") as logs: 
            logs.write(f"{player_idx} , {player_name}, no playoff OR regular season data \n")
        
    return career_game_logs

# %%
k, w = 0, 1000
player_dfs = []
for num,(index, row) in enumerate(df.iloc[k:w].iterrows()):
    print(k + num)
    
    if (num + 1) % 10 == 0:
        game_logs = pd.concat([player for player in player_dfs],ignore_index=True,sort=False)
        game_logs.to_csv(f"{advDataDir}/test_adv_game_logs.csv",index=False)
        print("df shape",game_logs.shape)
    
    career_game_logs = get_career_game_logs(row)
    player_dfs.append(career_game_logs)
    
    try:
        print(career_game_logs.shape)
    except:
        print("both dfs are None")
    
game_logs = pd.concat([player for player in player_dfs],ignore_index=True,sort=False)
print("\n")
print(game_logs.shape)

game_logs.to_csv(f"{advDataDir}/test_adv_game_logs - extract {k}-{w-1}.csv"
                 ,index=False)
# Out:
# 0
# abdelal01 Alaa Abdelnaby
# (273, 30)
# 1
# abdulza01 Zaid Abdul-Aziz
# (521, 28)
# 2
# abdulka01 Kareem Abdul-Jabbar*
# (1797, 30)
# 3
# abdulma02 Mahmoud Abdul-Rauf
# (663, 30)
# 4
# abdulta01 Tariq Abdul-Wahad
# (305, 30)
# 5
# abdursh01 Shareef Abdur-Rahim
# (939, 30)
# 6
# abernto01 Tom Abernethy
# (331, 29)
# 7
# ablefo01 Forest Able
# (1, 22)
# 8
# abramjo01 John Abramovic
# (56, 22)
# 9
# df shape (4886, 30)
# abrinal01 Álex Abrines
# (229, 30)
# 10
# ackeral01 Alex Acker
# (161, 29)
# 11
# ackerdo01 Don Ackerman
# (31, 23)
# 12
# acresma01 Mark Acres
# (394, 30)
# 13
# actonbu01 Bud Acton
# (23, 22)
# 14
# acyqu01 Quincy Acy
# (477, 29)
# 15
# adamsal01 Alvan Adams
# (1066, 30)
# 16
# adamsdo01 Don Adams
# (519, 28)
# 17
# adamsge01 George Adams
# (223, 28)
# 18
# adamsha01 Hassan Adams
# (118, 30)
# 19
# df shape (8127, 30)
# adamsja01 Jaylen Adams
# (82, 29)
# 20
# adamsjo01 Jordan Adams
# (179, 31)
# 21
# adamsmi01 Michael Adams
# (673, 30)
# 22
# adamsst01 Steven Adams
# (609, 31)
# 23
# addisra01 Rafael Addison
# (400, 30)
# 24
# adebaba01 Bam Adebayo
# (234, 30)
# 25
# adelde01 Deng Adel
# (38, 29)
# 26
# adelmri01 Rick Adelman
# (482, 25)
# 27
# adrieje01 Jeff Adrien
# (239, 29)
# 28
# afflaar01 Arron Afflalo
# (922, 31)
# 29
# df shape (11985, 31)
# agerma01 Maurice Ager
# (258, 30)
# 30
# aguirma01 Mark Aguirre
# (1025, 30)
# 31
# ahearbl01 Blake Ahearn
# (41, 30)
# 32
# aingeda01 Danny Ainge
# (1235, 30)
# 33
# aitchma01 Matthew Aitch
# (45, 26)
# 34
# ajincal01 Alexis Ajinça
# (562, 31)
# 35
# akinhe01 Henry Akin
# (89, 26)
# 36
# akognjo01 Josh Akognon
# (3, 29)
# 37
# akoonde01 DeVaughn Akoon-Purcell
# (28, 29)
# 38
# alabiso01 Solomon Alabi
# (148, 29)
# 39
# df shape (15419, 31)
# alarima01 Mark Alarie
# (329, 30)
# 40
# alcorga01 Gary Alcorn
# (79, 22)
# 41
# aldemfu01 Furkan Aldemir
# (59, 29)
# 42
# aldrico01 Cole Aldrich
# (657, 31)
# 43
# aldrila01 LaMarcus Aldridge
# (1183, 30)
# 44
# aleksch01 Chuck Aleksinas
# (74, 29)
# 45
# alexacl01 Cliff Alexander
# (82, 29)
# 46
# alexaco01 Cory Alexander
# (419, 30)
# 47
# alexaco02 Courtney Alexander
# (239, 30)
# 48
# alexaga01 Gary Alexander
# (11, 29)
# 49
# df shape (18551, 31)
# alexajo01 Joe Alexander
# (163, 29)
# 50
# alexavi01 Victor Alexander
# (324, 30)
# 51
# alexani01 Nickeil Alexander-Walker
# (64, 29)
# 52
# alforst01 Steve Alford
# (182, 30)
# 53
# alkinra01 Rawle Alkins
# (82, 29)
# 54
# allenbi01 Bill Allen
# (36, 25)
# 55
# allenbo01 Bob Allen
# (28, 23)
# 56
# allengr01 Grayson Allen
# (152, 31)
# 57
# allenja01 Jarrett Allen
# (233, 30)
# 58
# allenje01 Jerome Allen
# (121, 29)
# 59
# df shape (19936, 31)
# allenka01 Kadeem Allen
# (187, 29)
# 60
# allenla01 Lavoy Allen
# (519, 31)
# 61
# allenlu01 Lucius Allen
# (744, 28)
# 62
# allenma01 Malik Allen
# (763, 30)
# 63
# allenra01 Randy Allen
# (70, 29)
# 64
# allenra02 Ray Allen*
# (1570, 30)
# 65
# allento01 Tony Allen
# (1221, 31)
# 66
# allenwi01 Willie Allen
# (6, 26)
# 67
# allisod01 Odis Allison
# (35, 22)
# 68
# allrela01 Lance Allred
# (17, 29)
# 69
# df shape (25068, 31)
# allumda01 Darrell Allums
# (22, 28)
# 70
# almonmo01 Morris Almond
# (170, 29)
# 71
# alstode01 Derrick Alston
# (144, 29)
# 72
# alstora01 Rafer Alston
# (854, 30)
# 73
# alumape01 Peter Aluma
# (7, 29)
# 74
# amaecjo01 John Amaechi
# (363, 30)
# 75
# amayaas01 Ashraf Amaya
# (133, 29)
# 76
# aminual01 Al-Farouq Aminu
# (827, 30)
# 77
# amundlo01 Lou Amundson
# (710, 31)
# 78
# anderbo01 Bob Anderegg
# (31, 22)
# 79
# df shape (28329, 31)
# anderch01 Chris Andersen
# (1049, 31)
# 80
# anderda03 David Andersen
# (166, 29)
# 81
# anderal01 Alan Anderson
# (566, 31)
# 82
# anderan01 Andrew Anderson
# (217, 26)
# 83
# anderan02 Antonio Anderson
# (11, 29)
# 84
# andercl01 Cliff Anderson
# (82, 26)
# 85
# anderda01 Dan Anderson
# (144, 26)
# 86
# anderda02 Dan Anderson
# (95, 24)
# 87
# anderde01 Derek Anderson
# (818, 30)
# 88
# anderdw01 Dwight Anderson
# (5, 28)
# 89
# df shape (31482, 31)
# anderer01 Eric Anderson
# (0, 30)
# 90
# andergr01 Greg Anderson
# (729, 30)
# 91
# anderjj01 J.J. Anderson
# (157, 30)
# 92
# anderja01 James Anderson
# (393, 31)
# 93
# anderje01 Jerome Anderson
# (49, 25)
# 94
# anderju01 Justin Anderson
# (349, 31)
# 95
# anderke01 Kenny Anderson
# (969, 30)
# 96
# anderki01 Kim Anderson
# (21, 27)
# 97
# anderky01 Kyle Anderson
# (513, 31)
# 98
# andermi01 Michael Anderson
# (36, 29)
# 99
# df shape (34698, 31)
# anderni01 Nick Anderson
# (960, 30)
# 100
# anderri01 Richard Anderson
# (422, 30)
# 101
# anderro01 Ron Anderson
# (691, 30)
# 102
# anderry01 Ryan Anderson
# (954, 31)
# 103
# andersh01 Shandon Anderson
# (844, 30)
# 104
# anderwi01 Willie Anderson
# (628, 30)
# 105
# anderwa01 Wally Anderzunas
# (44, 22)
# 106
# andrima01 Martynas Andriuškevičius
# (82, 29)
# 107
# anieldo01 Don Anielak
# (1, 22)
# 108
# anigbik01 Ike Anigbogu
# (136, 29)
# 109
# df shape (39460, 31)
# anslemi01 Michael Ansley
# (149, 29)
# 110
# anstech01 Chris Anstey
# (204, 29)
# 111
# antetgi01 Giannis Antetokounmpo
# (590, 30)
# 112
# antetko01 Kostas Antetokounmpo
# (145, 29)
# 113
# antetth01 Thanasis Antetokounmpo
# (71, 29)
# 114
# anthoca01 Carmelo Anthony
# (1388, 30)
# 115
# anthogr01 Greg Anthony
# (896, 30)
# 116
# anthojo01 Joel Anthony
# (850, 31)
# 117
# anticpe01 Pero Antić
# (187, 31)
# 118
# anunoog01 OG Anunoby
# (262, 31)
# 119
# df shape (44202, 31)
# applike01 Keith Appling
# (11, 29)
# 120
# araujra01 Rafael Araújo
# (241, 30)
# 121
# arcenst01 Stacey Arceneaux
# (7, 22)
# 122
# archiro01 Robert Archibald
# (96, 29)
# 123
# architi01 Tiny Archibald*
# (934, 29)
# 124
# arcidry01 Ryan Arcidiacono
# (229, 29)
# 125
# ardji01 Jim Ard
# (469, 29)
# 126
# arenagi01 Gilbert Arenas
# (781, 30)
# 127
# arizatr01 Trevor Ariza
# (1381, 30)
# 128
# arizipa01 Paul Arizin*
# (762, 23)
# 129
# df shape (49113, 31)
# arlaujo01 Joe Arlauckas
# (9, 29)
# 130
# armstbj01 B.J. Armstrong
# (884, 30)
# 131
# armstbo01 Bob Armstrong
# (20, 22)
# 132
# armstbr01 Brandon Armstrong
# (192, 30)
# 133
# armstcu01 Curly Armstrong
# (159, 23)
# 134
# armstda01 Darrell Armstrong
# (979, 30)
# 135
# armsthi01 Hilton Armstrong
# (456, 30)
# 136
# armstta01 Tate Armstrong
# (91, 27)
# 137
# arnelje01 Jesse Arnelle
# (31, 22)
# 138
# arnetja01 Jay Arnette
# (123, 23)
# 139
# df shape (52057, 31)
# arnzebo01 Bob Arnzen
# (109, 28)
# 140
# arroyca01 Carlos Arroyo
# (738, 30)
# 141
# arthuda01 Darrell Arthur
# (832, 30)
# 142
# arthujo01 John Arthurs
# (11, 22)
# 143
# artisja01 Jamel Artis
# (82, 29)
# 144
# asikom01 Ömer Aşık
# (676, 30)
# 145
# askewvi01 Vincent Askew
# (565, 30)
# 146
# askinke01 Keith Askins
# (552, 30)
# 147
# asmondo01 Don Asmonga
# (7, 22)
# 148
# athadi01 Dick Atha
# (41, 22)
# 149
# df shape (55670, 31)
# atkinch01 Chucky Atkins
# (915, 30)
# 150
# attleal01 Al Attles*
# (772, 23)
# 151
# aubucch01 Chet Aubuchon
# (29, 22)
# 152
# augmost01 Stacey Augmon
# (1247, 30)
# 153
# augusdj01 D.J. Augustin
# (982, 30)
# 154
# augusja01 James Augustine
# (164, 30)
# 155
# austiis01 Isaac Austin
# (538, 30)
# 156
# austijo01 Johnny Austin
# (43, 25)
# 157
# austike01 Ken Austin
# (7, 28)
# 158
# aventan01 Anthony Avent
# (397, 30)
# 159
# df shape (60764, 31)
# averibi01 Bird Averitt
# (395, 29)
# 160
# averywi01 William Avery
# (202, 30)
# 161
# awtrede01 Dennis Awtrey
# (792, 29)
# 162
# ayongu01 Gustavo Ayón
# (242, 31)
# 163
# pendeje02 Jeff Ayres
# (481, 31)
# 164
# aytonde01 Deandre Ayton
# (147, 29)
# 165
# azubuke01 Kelenna Azubuike
# (378, 30)
# 166
# babbch01 Chris Babb
# (23, 29)
# 167
# babbilu01 Luke Babbitt
# (601, 31)
# 168
# babicmi01 Miloš Babić
# (21, 29)
# 169
# df shape (64046, 31)
# bachjo01 Johnny Bach
# (34, 22)
# 170
# bacondw01 Dwayne Bacon
# (229, 29)
# 171
# baconhe01 Henry Bacon
# (49, 28)
# 172
# baechji01 Jim Baechtold
# (330, 23)
# 173
# bagarda01 Dalibor Bagarić
# (157, 29)
# 174
# baglejo01 John Bagley
# (684, 30)
# 175
# baglema01 Marvin Bagley
# (146, 29)
# 176
# baileca01 Carl Bailey
# (1, 28)
# 177
# bailegu01 Gus Bailey
# (147, 29)
# 178
# baileja01 James Bailey
# (609, 30)
# 179
# df shape (66432, 31)
# baileth01 Thurl Bailey
# (998, 30)
# 180
# baileto01 Toby Bailey
# (101, 30)
# 181
# bairsca01 Cameron Bairstow
# (164, 29)
# 182
# bakerji01 Jimmie Baker
# (5, 27)
# 183
# bakerla01 LaMark Baker
# (4, 29)
# 184
# bakerma01 Maurice Baker
# (10, 29)
# 185
# bakerno01 Norm Baker
# (4, 22)
# 186
# bakerro01 Ron Baker
# (201, 29)
# 187
# bakervi01 Vin Baker
# (928, 30)
# 188
# baldwwa01 Wade Baldwin
# (226, 31)
# 189
# df shape (69073, 31)
# balkmre01 Renaldo Balkman
# (444, 30)
# 190
# ballce01 Cedric Ball
# (7, 29)
# 191
# balllo01 Lonzo Ball
# (228, 29)
# 192
# ballagr01 Greg Ballard
# (867, 30)
# 193
# baltihe01 Herschel Baltimore
# (61, 23)
# 194
# bambamo01 Mohamed Bamba
# (147, 29)
# 195
# banksge01 Gene Banks
# (495, 30)
# 196
# banksma01 Marcus Banks
# (669, 30)
# 197
# bankswa01 Walker Banks
# (16, 25)
# 198
# bannike01 Ken Bannister
# (253, 29)
# 199
# df shape (72260, 31)
# bantomi01 Mike Bantom
# (736, 29)
# 200
# barbejo01 John Barber
# (5, 22)
# 201
# barbole01 Leandro Barbosa
# (1214, 31)
# 202
# bardost01 Steve Bardo
# (33, 29)
# 203
# bareajo01 J.J. Barea
# (1164, 31)
# 204
# bargnan01 Andrea Bargnani
# (786, 30)
# 205
# barkecl01 Cliff Barker
# (149, 23)
# 206
# barketo01 Tom Barker
# (98, 27)
# 207
# barklch01 Charles Barkley*
# (1237, 30)
# 208
# barkler01 Erick Barkley
# (78, 29)
# 209
# df shape (77760, 31)
# barksdo01 Don Barksdale*
# (275, 23)
# 210
# barneha02 Harrison Barnes
# (700, 30)
# 211
# barneha01 Harry Barnes
# (22, 22)
# 212
# barneji01 Jim Barnes
# (466, 23)
# 213
# barnema01 Marvin Barnes
# (314, 29)
# 214
# barnema02 Matt Barnes
# (1168, 31)
# 215
# barnedi01 Dick Barnett
# (1073, 25)
# 216
# barneji02 Jim Barnett
# (762, 25)
# 217
# barnena01 Nathaniel Barnett
# (12, 27)
# 218
# barnhjo01 John Barnhill
# (619, 27)
# 219
# df shape (83171, 31)
# barnhno01 Norton Barnhill
# (4, 24)
# 220
# barnhle01 Leo Barnhorst
# (354, 23)
# 221
# barrjo01 John Barr
# (57, 22)
# 222
# barrmi01 Mike Barr
# (327, 28)
# 223
# barrmo01 Moe Barr
# (31, 22)
# 224
# barrean01 Andre Barrett
# (163, 29)
# 225
# barreer01 Ernie Barrett
# (139, 23)
# 226
# barremi01 Mike Barrett
# (206, 28)
# 227
# barrerj01 RJ Barrett
# (66, 29)
# 228
# barroea01 Earl Barron
# (361, 31)
# 229
# df shape (84879, 31)
# barroda01 Dana Barros
# (920, 30)
# 230
# barrybr01 Brent Barry
# (1138, 30)
# 231
# barrydr01 Drew Barry
# (90, 30)
# 232
# barryjo01 Jon Barry
# (1014, 30)
# 233
# barryri01 Rick Barry*
# (1125, 29)
# 234
# barteed01 Ed Bartels
# (31, 22)
# 235
# bartovi01 Vic Bartolome
# (36, 22)
# 236
# bartowi01 Will Barton
# (664, 31)
# 237
# basdeed01 Eddie Basden
# (81, 29)
# 238
# baskeje01 Jerry Baskerville
# (21, 24)
# 239
# df shape (89999, 31)
# bassbr01 Brandon Bass
# (1032, 31)
# 240
# basseti01 Tim Bassett
# (497, 29)
# 241
# bastoma01 Maceo Baston
# (280, 30)
# 242
# bateeme01 Mengke Bateer
# (95, 29)
# 243
# batesbi01 Billy Ray Bates
# (193, 29)
# 244
# bateske01 Keita Bates-Diop
# (145, 29)
# 245
# batises01 Esteban Batista
# (164, 29)
# 246
# batismi01 Mike Batiste
# (82, 29)
# 247
# battito01 Tony Battie
# (1191, 30)
# 248
# battish01 Shane Battier
# (1167, 31)
# 249
# df shape (94845, 31)
# battljo01 John Battle
# (667, 30)
# 250
# battlke01 Kenny Battle
# (134, 30)
# 251
# battoda01 Dave Batton
# (58, 28)
# 252
# battsll01 Lloyd Batts
# (58, 27)
# 253
# batumni01 Nicolas Batum
# (991, 31)
# 254
# baumjo01 Johnny Baum
# (277, 28)
# 255
# baumhfr01 Frankie Baumholtz
# (45, 22)
# 256
# baxtelo01 Lonny Baxter
# (241, 29)
# 257
# bayleje01 Jerryd Bayless
# (923, 31)
# 258
# bayloel01 Elgin Baylor*
# (980, 23)
# 259
# df shape (99219, 31)
# bayneho01 Howard Bayne
# (71, 26)
# 260
# baynear01 Aron Baynes
# (678, 31)
# 261
# bazarse01 Sergei Bazarevich
# (10, 29)
# 262
# bazemke01 Kent Bazemore
# (684, 31)
# 263
# bazleda01 Darius Bazley
# (64, 29)
# 264
# beached01 Ed Beach
# (13, 22)
# 265
# bealbr01 Bradley Beal
# (678, 30)
# 266
# beardal01 Al Beard
# (13, 25)
# 267
# beardbu01 Butch Beard
# (636, 28)
# 268
# beardra01 Ralph Beard
# (134, 23)
# 269
# df shape (102200, 31)
# beaslch01 Charles Beasley
# (301, 26)
# 270
# beaslje01 Jerome Beasley
# (13, 29)
# 271
# beasljo01 John Beasley
# (550, 28)
# 272
# beaslma01 Malik Beasley
# (312, 30)
# 273
# beaslmi01 Michael Beasley
# (784, 31)
# 274
# beatyze01 Zelmo Beaty*
# (1003, 28)
# 275
# beaubro01 Rodrigue Beaubois
# (318, 30)
# 276
# beckby01 Byron Beck
# (812, 28)
# 277
# beckco01 Corey Beck
# (127, 30)
# 278
# becker01 Ernie Beck
# (394, 23)
# 279
# df shape (106814, 31)
# beckear01 Arthur Becker
# (439, 28)
# 280
# beckemo01 Moe Becker
# (42, 22)
# 281
# bedelbo01 Bob Bedell
# (278, 26)
# 282
# bedfowi01 William Bedford
# (252, 30)
# 283
# beendha01 Hank Beenders
# (110, 23)
# 284
# behagro01 Ron Behagen
# (396, 29)
# 285
# behnkel01 Elmer Behnke
# (4, 22)
# 286
# belinma01 Marco Belinelli
# (1098, 30)
# 287
# bellch01 Charlie Bell
# (510, 30)
# 288
# bellde01 Dennis Bell
# (66, 25)
# 289
# df shape (110009, 31)
# belljo01 Jordan Bell
# (266, 31)
# 290
# bellra01 Raja Bell
# (950, 30)
# 291
# belltr01 Troy Bell
# (38, 29)
# 292
# bellwh01 Whitey Bell
# (36, 22)
# 293
# bellawa01 Walt Bellamy*
# (1089, 25)
# 294
# bembrde01 DeAndre' Bembry
# (313, 29)
# 295
# bemorir01 Irv Bemoras
# (133, 23)
# 296
# benbole01 Leon Benbow
# (115, 25)
# 297
# bendedr01 Dragan Bender
# (307, 29)
# 298
# bendejo01 Jonathan Bender
# (505, 30)
# 299
# df shape (113761, 31)
# benimje01 Jerrelle Benimon
# (5, 29)
# 300
# benjabe01 Benoit Benjamin
# (841, 30)
# 301
# benjaco01 Corey Benjamin
# (194, 29)
# 302
# bennean01 Anthony Bennett
# (258, 29)
# 303
# benneel01 Elmer Bennett
# (33, 29)
# 304
# bennema01 Mario Bennett
# (117, 30)
# 305
# benneme01 Mel Bennett
# (204, 28)
# 306
# bennesp01 Spider Bennett
# (59, 25)
# 307
# benneto01 Tony Bennett
# (152, 30)
# 308
# bennewi01 Winston Bennett
# (141, 30)
# 309
# df shape (115765, 31)
# benoida01 David Benoit
# (567, 30)
# 310
# bensoke02 Keith Benson
# (6, 29)
# 311
# bensoke01 Kent Benson
# (709, 30)
# 312
# bentibe01 Ben Bentil
# (5, 29)
# 313
# bercege01 Gene Berce
# (3, 22)
# 314
# bergega01 Gary Bergen
# (6, 22)
# 315
# berghla01 Larry Bergh
# (20, 25)
# 316
# berryri01 Ricky Berry
# (64, 29)
# 317
# berrywa01 Walter Berry
# (212, 30)
# 318
# bertada02 Dairis Bertāns
# (18, 29)
# 319
# df shape (117375, 31)
# bertada01 Dāvis Bertāns
# (338, 31)
# 320
# beshode01 Del Beshore
# (69, 28)
# 321
# besttr01 Travis Best
# (809, 30)
# 322
# beverpa01 Patrick Beverley
# (655, 31)
# 323
# bhullsi01 Sim Bhullar
# (5, 29)
# 324
# bialowe01 Wesley Bialosuknia
# (69, 25)
# 325
# biancal01 Al Bianchi
# (742, 23)
# 326
# biasaha01 Hank Biasatti
# (6, 22)
# 327
# bibbyhe01 Henry Bibby
# (747, 29)
# 328
# bibbymi01 Mike Bibby
# (1179, 30)
# 329
# df shape (121994, 31)
# biedeed01 Ed Biedenbach
# (7, 22)
# 330
# biedran01 Andris Biedriņš
# (784, 31)
# 331
# bielkdo01 Don Bielke
# (7, 22)
# 332
# bigelbo01 Bob Bigelow
# (94, 27)
# 333
# billili01 Lionel Billingy
# (45, 27)
# 334
# billuch01 Chauncey Billups
# (1431, 30)
# 335
# bingda01 Dave Bing*
# (932, 28)
# 336
# biniojo01 Joe Binion
# (11, 29)
# 337
# birchkh01 Khem Birch
# (234, 30)
# 338
# birdja01 Jabari Bird
# (82, 29)
# 339
# df shape (125621, 31)
# birdje01 Jerry Bird
# (11, 22)
# 340
# birdla01 Larry Bird*
# (1066, 30)
# 341
# birdsot01 Otis Birdsong
# (731, 30)
# 342
# bishoga01 Gale Bishop
# (58, 23)
# 343
# bitadgo01 Goga Bitadze
# (65, 29)
# 344
# biyombi01 Bismack Biyombo
# (729, 31)
# 345
# bjeline01 Nemanja Bjelica
# (397, 30)
# 346
# blabuw01 Uwe Blab
# (242, 30)
# 347
# blackch01 Charlie Black
# (136, 23)
# 348
# blackno01 Norman Black
# (3, 28)
# 349
# df shape (129059, 31)
# blackta01 Tarik Black
# (327, 31)
# 350
# blackto01 Tom Black
# (70, 22)
# 351
# blackro01 Rolando Blackman
# (1049, 30)
# 352
# blackal01 Alex Blackwell
# (27, 29)
# 353
# blackco01 Cory Blackwell
# (60, 29)
# 354
# blackja01 James Blackwell
# (13, 29)
# 355
# blackna01 Nate Blackwell
# (10, 29)
# 356
# blairde01 DeJuan Blair
# (591, 31)
# 357
# blakest01 Steve Blake
# (1085, 31)
# 358
# blakean01 Antonio Blakeney
# (164, 29)
# 359
# df shape (132455, 31)
# blalowi01 Will Blalock
# (82, 29)
# 360
# blanege01 George Blaney
# (36, 22)
# 361
# blankla01 Lance Blanks
# (143, 30)
# 362
# blantri01 Ricky Blanton
# (2, 29)
# 363
# blatcan01 Andray Blatche
# (747, 30)
# 364
# blaylmo01 Mookie Blaylock
# (969, 30)
# 365
# bledser01 Eric Bledsoe
# (827, 30)
# 366
# blevile01 Leon Blevins
# (1, 22)
# 367
# blockjo01 John Block
# (616, 25)
# 368
# bloommi01 Mike Bloom
# (95, 23)
# 369
# df shape (135973, 31)
# blossja01 Jaron Blossomgame
# (60, 29)
# 370
# blounco01 Corie Blount
# (788, 30)
# 371
# blounma01 Mark Blount
# (747, 30)
# 372
# blueva01 Vander Blue
# (48, 29)
# 373
# blumera01 Ray Blume
# (49, 28)
# 374
# bobbne01 Nelson Bobb
# (224, 23)
# 375
# bobbito01 Tony Bobbitt
# (15, 29)
# 376
# bockhbu01 Bucky Bockhorn
# (500, 23)
# 377
# boerwto01 Tom Boerwinkle
# (671, 28)
# 378
# boganke01 Keith Bogans
# (855, 31)
# 379
# df shape (139930, 31)
# bogdabo01 Bogdan Bogdanović
# (228, 29)
# 380
# bogdabo02 Bojan Bogdanović
# (505, 30)
# 381
# boguemu01 Muggsy Bogues
# (944, 30)
# 382
# bogutan01 Andrew Bogut
# (1099, 31)
# 383
# bohanet01 Etdrick Bohannon
# (57, 29)
# 384
# bolma01 Manute Bol
# (653, 30)
# 385
# boldejo01 Jonah Bolden
# (138, 31)
# 386
# boldema01 Marques Bolden
# (4, 29)
# 387
# bolgebi01 Bill Bolger
# (20, 22)
# 388
# bolomjo01 Joel Bolomboy
# (119, 31)
# 389
# df shape (143697, 31)
# bolstdo01 Doug Bolstorff
# (4, 22)
# 390
# bonsage01 George Bon Salle
# (3, 22)
# 391
# bondph01 Phil Bond
# (7, 27)
# 392
# bondwa01 Walter Bond
# (153, 30)
# 393
# bonejo01 Jordan Bone
# (66, 29)
# 394
# boneyde01 Dexter Boney
# (9, 29)
# 395
# bongais01 Isaac Bonga
# (146, 29)
# 396
# bonharo01 Ron Bonham
# (128, 26)
# 397
# bonnean01 Anthony Bonner
# (341, 30)
# 398
# bonnema01 Matt Bonner
# (1074, 31)
# 399
# df shape (145628, 31)
# bookebu01 Butch Booker
# (12, 25)
# 400
# bookede01 Devin Booker
# (392, 29)
# 401
# bookeme01 Melvin Booker
# (34, 29)
# 402
# booketr01 Trevor Booker
# (655, 31)
# 403
# boonejo01 Josh Boone
# (328, 30)
# 404
# boonero01 Ron Boone
# (1124, 29)
# 405
# boothca01 Calvin Booth
# (674, 30)
# 406
# boothke01 Keith Booth
# (56, 29)
# 407
# boozebo01 Bob Boozer
# (921, 23)
# 408
# boozeca01 Carlos Boozer
# (1107, 30)
# 409
# df shape (150931, 31)
# borchcu01 Curtis Borchardt
# (101, 29)
# 410
# bornhja01 Jake Bornheimer
# (77, 23)
# 411
# borrela01 Lazaro Borrell
# (29, 30)
# 412
# borsaik01 Ike Borsavage
# (20, 22)
# 413
# borylvi01 Vince Boryla
# (318, 23)
# 414
# boshch01 Chris Bosh
# (1151, 31)
# 415
# bostiji01 Jim Bostic
# (4, 27)
# 416
# bostola01 Lawrence Boston
# (13, 28)
# 417
# bosweto01 Tom Boswell
# (385, 29)
# 418
# bouchch01 Chris Boucher
# (228, 31)
# 419
# df shape (153257, 31)
# boumtru01 Ruben Boumtje-Boumtje
# (86, 29)
# 420
# bovendo01 Don Boven
# (196, 23)
# 421
# bowdlca01 Cal Bowdler
# (239, 29)
# 422
# bowenbr02 Brian Bowen
# (65, 29)
# 423
# bowenbr01 Bruce Bowen
# (1031, 30)
# 424
# bowenry01 Ryan Bowen
# (716, 30)
# 425
# bowento01 Tommie Bowens
# (210, 26)
# 426
# bowiean01 Anthony Bowie
# (524, 30)
# 427
# bowiesa01 Sam Bowie
# (540, 30)
# 428
# bowlior01 Orbie Bowling
# (12, 25)
# 429
# df shape (156876, 31)
# bowmair01 Ira Bowman
# (0, 30)
# 430
# bowmaky01 Ky Bowman
# (65, 29)
# 431
# bowmana01 Nate Bowman
# (288, 27)
# 432
# boycedo01 Donnie Boyce
# (66, 30)
# 433
# boydde01 Dennis Boyd
# (5, 27)
# 434
# boydfr01 Freddie Boyd
# (327, 27)
# 435
# boydke01 Ken Boyd
# (6, 24)
# 436
# boykiea01 Earl Boykins
# (791, 30)
# 437
# boykoha01 Harry Boykoff
# (109, 22)
# 438
# boynewi01 Winford Boynes
# (176, 28)
# 439
# df shape (158709, 31)
# bozemce01 Cedric Bozeman
# (29, 29)
# 440
# bracest01 Steve Bracey
# (197, 25)
# 441
# brackcr01 Craig Brackins
# (148, 29)
# 442
# braddga01 Gary Bradds
# (274, 26)
# 443
# bradlal02 Alex Bradley
# (39, 28)
# 444
# bradlal01 Alonzo Bradley
# (104, 29)
# 445
# bradlav01 Avery Bradley
# (826, 31)
# 446
# bradlbi02 Bill Bradley
# (59, 26)
# 447
# bradlbi01 Bill Bradley*
# (837, 25)
# 448
# bradlch01 Charles Bradley
# (119, 29)
# 449
# df shape (161341, 31)
# bradldu01 Dudley Bradley
# (630, 30)
# 450
# bradlji01 Jim Bradley
# (110, 28)
# 451
# bradljo01 Joe Bradley
# (43, 22)
# 452
# bradlmi01 Michael Bradley
# (294, 30)
# 453
# bradlsh01 Shawn Bradley
# (953, 30)
# 454
# bradlto01 Tony Bradley
# (244, 31)
# 455
# bradtma01 Mark Bradtke
# (69, 29)
# 456
# braggma01 Marques Bragg
# (53, 29)
# 457
# braggto01 Torraye Braggs
# (37, 29)
# 458
# bramlaj01 A.J. Bramlett
# (19, 29)
# 459
# df shape (163793, 31)
# brancad01 Adrian Branch
# (142, 30)
# 460
# brandel01 Elton Brand
# (1372, 31)
# 461
# brandte01 Terrell Brandon
# (785, 30)
# 462
# brannbo01 Bob Brannum
# (363, 23)
# 463
# bransbr01 Brad Branson
# (72, 28)
# 464
# bransje01 Jesse Branson
# (83, 26)
# 465
# brantja01 Jarrell Brantley
# (64, 29)
# 466
# brascji01 Jim Brasco
# (20, 22)
# 467
# bratzmi01 Mike Bratz
# (623, 30)
# 468
# braunca01 Carl Braun*
# (828, 23)
# 469
# df shape (168145, 31)
# brazdig01 Ignas Brazdeikis
# (66, 29)
# 470
# breauti01 Tim Breaux
# (106, 29)
# 471
# bremejr01 J.R. Bremer
# (147, 30)
# 472
# brennpe01 Pete Brennan
# (18, 23)
# 473
# brennto01 Tom Brennan
# (11, 22)
# 474
# breuera01 Randy Breuer
# (741, 30)
# 475
# breweco01 Corey Brewer
# (965, 30)
# 476
# breweja01 Jamison Brewer
# (114, 30)
# 477
# breweji01 Jim Brewer
# (734, 29)
# 478
# brewero01 Ron Brewer
# (517, 30)
# 479
# df shape (171564, 31)
# brewero02 Ronnie Brewer
# (677, 31)
# 480
# brezepr01 Primož Brezec
# (600, 30)
# 481
# brianfr01 Frankie Brian
# (481, 23)
# 482
# brickfr01 Frank Brickowski
# (792, 30)
# 483
# bridgju01 Junior Bridgeman
# (898, 30)
# 484
# bridgbi01 Bill Bridges
# (1039, 25)
# 485
# bridgmi01 Mikal Bridges
# (147, 29)
# 486
# bridgmi02 Miles Bridges
# (147, 29)
# 487
# brighal01 Al Brightman
# (57, 22)
# 488
# brindau01 Aud Brindley
# (0, 23)
# 489
# df shape (176402, 31)
# briscis01 Isaiah Briscoe
# (79, 29)
# 490
# briskjo01 John Brisker
# (330, 27)
# 491
# brissos01 Oshae Brissett
# (64, 29)
# 492
# bristal01 Allan Bristow
# (722, 29)
# 493
# brittty01 Tyrone Britt
# (11, 22)
# 494
# brittwa01 Wayman Britt
# (7, 27)
# 495
# brittmi01 Mike Brittain
# (39, 30)
# 496
# brittda01 Dave Britton
# (2, 28)
# 497
# brockjo01 Jon Brockman
# (230, 29)
# 498
# broekry01 Ryan Broekhoff
# (136, 29)
# 499
# df shape (178022, 31)
# brogaji01 Jim Brogan
# (121, 28)
# 500
# brogdma01 Malcolm Brogdon
# (339, 31)
# 501
# brokaga01 Gary Brokaw
# (246, 28)
# 502
# brookpr01 Price Brookfield
# (60, 22)
# 503
# brookcl01 Clarence Brookins
# (7, 25)
# 504
# brookaa01 Aaron Brooks
# (871, 31)
# 505
# brookdi01 Dillon Brooks
# (229, 29)
# 506
# brookke01 Kevin Brooks
# (128, 30)
# 507
# brookma01 MarShon Brooks
# (284, 30)
# 508
# brookmi01 Michael Brooks
# (319, 30)
# 509
# df shape (180626, 31)
# brooksc01 Scott Brooks
# (776, 30)
# 510
# brownan01 Andre Brown
# (140, 29)
# 511
# brownan02 Anthony Brown
# (178, 29)
# 512
# brownbo01 Bob Brown
# (82, 22)
# 513
# brownbo02 Bobby Brown
# (281, 31)
# 514
# brownbr01 Bruce Brown
# (152, 30)
# 515
# brownch02 Charlie Brown
# (67, 29)
# 516
# brownch01 Chucky Brown
# (785, 30)
# 517
# brownda02 Damone Brown
# (59, 29)
# 518
# brownda01 Darrell Brown
# (3, 22)
# 519
# df shape (183149, 31)
# brownde01 Dee Brown
# (705, 30)
# 520
# brownde03 Dee Brown
# (105, 30)
# 521
# brownde04 Derrick Brown
# (232, 30)
# 522
# brownde02 Devin Brown
# (573, 30)
# 523
# browner01 Ernest Brown
# (8, 29)
# 524
# brownfr01 Fred Brown
# (1046, 29)
# 525
# brownge01 George Brown
# (1, 22)
# 526
# brownge02 Gerald Brown
# (40, 30)
# 527
# brownha01 Harold Brown
# (52, 22)
# 528
# brownja01 Jabari Brown
# (20, 29)
# 529
# df shape (185931, 31)
# brownja02 Jaylen Brown
# (356, 31)
# 530
# brownjo01 John Brown
# (492, 29)
# 531
# brownke01 Kedrick Brown
# (245, 30)
# 532
# brownkw01 Kwame Brown
# (939, 30)
# 533
# brownla01 Larry Brown*
# (421, 27)
# 534
# brownle01 Leon Brown
# (4, 22)
# 535
# brownle02 Lewis Brown
# (2, 28)
# 536
# brownlo01 Lorenzo Brown
# (249, 31)
# 537
# brownma01 Marcus Brown
# (38, 29)
# 538
# brownma02 Markel Brown
# (210, 31)
# 539
# df shape (188887, 31)
# brownmi01 Mike Brown
# (672, 30)
# 540
# brownmo01 Moses Brown
# (66, 29)
# 541
# brownmy01 Myron Brown
# (4, 29)
# 542
# brownpj01 P.J. Brown
# (1237, 30)
# 543
# brownra02 Randy Brown
# (749, 30)
# 544
# brownra01 Raymond Brown
# (19, 30)
# 545
# brownri01 Rickey Brown
# (347, 30)
# 546
# brownro01 Roger Brown*
# (714, 28)
# 547
# brownro02 Roger Brown
# (162, 29)
# 548
# brownsh01 Shannon Brown
# (662, 30)
# 549
# df shape (193519, 31)
# brownst01 Stan Brown
# (34, 22)
# 550
# brownst02 Sterling Brown
# (251, 31)
# 551
# brownti01 Tierre Brown
# (179, 29)
# 552
# brownto01 Tony Brown
# (377, 30)
# 553
# browntr01 Troy Brown
# (146, 29)
# 554
# brownji01 Jim Browne
# (34, 22)
# 555
# brundst01 Stanley Brundy
# (16, 29)
# 556
# brunkbr01 Brian Brunkhorst
# (3, 25)
# 557
# brunsge01 George Bruns
# (15, 28)
# 558
# brunsja01 Jalen Brunson
# (149, 29)
# 559
# df shape (194723, 31)
# brunsri01 Rick Brunson
# (527, 30)
# 560
# brussni01 Nicolás Brussino
# (106, 29)
# 561
# bryanem01 Em Bryant
# (592, 23)
# 562
# bryanjo01 Joe Bryant
# (636, 29)
# 563
# bryanko01 Kobe Bryant
# (1774, 31)
# 564
# bryanma01 Mark Bryant
# (1026, 30)
# 565
# bryanth01 Thomas Bryant
# (228, 29)
# 566
# bryanwa01 Wallace Bryant
# (104, 30)
# 567
# brynto01 Torgeir Bryn
# (3, 29)
# 568
# buccige01 George Bucci
# (34, 28)
# 569
# df shape (199753, 31)
# buckhjo01 Joe Buckhalter
# (67, 23)
# 570
# bucknst01 Steve Bucknall
# (18, 29)
# 571
# buckncl01 Cleveland Buckner
# (66, 22)
# 572
# buckngr01 Greg Buckner
# (754, 30)
# 573
# bucknqu01 Quinn Buckner
# (786, 30)
# 574
# buddda01 Dave Budd
# (352, 22)
# 575
# budinch01 Chase Budinger
# (557, 29)
# 576
# budkowa01 Walt Budko
# (259, 23)
# 577
# buechju01 Jud Buechler
# (848, 30)
# 578
# buforro01 Rodney Buford
# (341, 30)
# 579
# df shape (203801, 31)
# bullama01 Matt Bullard
# (714, 30)
# 580
# bullore01 Reggie Bullock
# (572, 31)
# 581
# buncela01 Larry Bunce
# (126, 25)
# 582
# bunchgr01 Greg Bunch
# (12, 27)
# 583
# buntdi01 Dick Bunt
# (27, 23)
# 584
# buntibi01 Bill Buntin
# (41, 22)
# 585
# buntibi02 Bill Bunting
# (141, 27)
# 586
# burdeti01 Ticky Burden
# (134, 28)
# 587
# burkepa01 Pat Burke
# (250, 30)
# 588
# burketr01 Trey Burke
# (501, 31)
# 589
# df shape (206319, 31)
# burkmro01 Roger Burkman
# (6, 28)
# 590
# burksal01 Alec Burks
# (734, 31)
# 591
# burksan01 Antonio Burks
# (128, 30)
# 592
# burleke01 Kevin Burleson
# (81, 29)
# 593
# burleto01 Tom Burleson
# (458, 29)
# 594
# burmaja01 Jack Burmaster
# (64, 23)
# 595
# burnsda01 David Burns
# (9, 28)
# 596
# burnsev01 Evers Burns
# (23, 29)
# 597
# burnsji01 Jim Burns
# (3, 25)
# 598
# burresc01 Scott Burrell
# (431, 30)
# 599
# df shape (208256, 31)
# burriar01 Art Burris
# (71, 22)
# 600
# burroju01 Junior Burrough
# (61, 29)
# 601
# burrobo01 Bob Burrow
# (81, 22)
# 602
# burtode02 Deonte Burton
# (151, 31)
# 603
# burtoed01 Ed Burton
# (15, 22)
# 604
# burtowi01 Willie Burton
# (332, 30)
# 605
# burttst01 Steve Burtt
# (101, 30)
# 606
# busedo01 Don Buse
# (1048, 30)
# 607
# bustida01 David Bustion
# (46, 28)
# 608
# butchdo01 Donnie Butcher
# (275, 22)
# 609
# df shape (210437, 31)
# butleal01 Al Butler
# (234, 22)
# 610
# butleca01 Caron Butler
# (1184, 31)
# 611
# butlegr01 Greg Butler
# (55, 29)
# 612
# butleja01 Jackie Butler
# (181, 29)
# 613
# butleji01 Jimmy Butler
# (759, 30)
# 614
# butlemi01 Mike Butler
# (262, 27)
# 615
# butlemi02 Mitchell Butler
# (420, 30)
# 616
# butlera01 Rasual Butler
# (1040, 31)
# 617
# buyckdw01 Dwight Buycks
# (170, 29)
# 618
# byarsde01 Derrick Byars
# (2, 29)
# 619
# df shape (214744, 31)
# bynuman01 Andrew Bynum
# (803, 31)
# 620
# bynumwi01 Will Bynum
# (518, 31)
# 621
# byrdwa01 Walter Byrd
# (21, 25)
# 622
# byrnema01 Marty Byrnes
# (261, 29)
# 623
# byrneto01 Tommy Byrnes
# (267, 23)
# 624
# bytzumi01 Michael Bytzura
# (59, 22)
# 625
# cabarza01 Žarko Čabarkapa
# (203, 29)
# 626
# cableba01 Barney Cable
# (372, 23)
# 627
# cabocbr01 Bruno Caboclo
# (428, 29)
# 628
# caffeja01 Jason Caffey
# (602, 30)
# 629
# df shape (218278, 31)
# cagemi01 Michael Cage
# (1204, 30)
# 630
# calabge01 Gerry Calabrese
# (103, 23)
# 631
# calatni01 Nick Calathes
# (168, 31)
# 632
# caldejo01 José Calderón
# (1180, 31)
# 633
# caldwad01 Adrian Caldwell
# (212, 30)
# 634
# caldwji01 Jim Caldwell
# (79, 26)
# 635
# caldwjo01 Joe Caldwell
# (843, 28)
# 636
# caldwke01 Kentavious Caldwell-Pope
# (559, 30)
# 637
# calhobi01 Bill Calhoun
# (460, 23)
# 638
# calhoco01 Corky Calhoun
# (560, 29)
# 639
# df shape (223646, 31)
# calipde01 Demetrius Calip
# (7, 29)
# 640
# callato01 Tom Callahan
# (11, 22)
# 641
# callori01 Rick Calloway
# (64, 29)
# 642
# calveer01 Ernie Calverley
# (165, 22)
# 643
# calvima01 Mack Calvin
# (829, 29)
# 644
# cambrde01 Dexter Cambridge
# (53, 29)
# 645
# cambyma01 Marcus Camby
# (1315, 31)
# 646
# campbel01 Elden Campbell
# (1251, 30)
# 647
# campbto01 Tony Campbell
# (728, 30)
# 648
# canaais01 Isaiah Canaan
# (391, 29)
# 649
# df shape (228460, 31)
# cancavl01 Vlatko Čančar
# (65, 29)
# 650
# cannola01 Larry Cannon
# (210, 27)
# 651
# capelca01 Clint Capela
# (536, 30)
# 652
# caracde01 Derrick Caracter
# (82, 29)
# 653
# cardfr01 Frank Card
# (321, 28)
# 654
# cardibr01 Brian Cardinal
# (765, 30)
# 655
# carlho01 Howie Carl
# (29, 22)
# 656
# carlich01 Chet Carlisle
# (51, 23)
# 657
# carlige01 Geno Carlisle
# (16, 29)
# 658
# carliri01 Rick Carlisle
# (200, 30)
# 659
# df shape (230735, 31)
# carlodo01 Don Carlos
# (56, 25)
# 660
# carlsal01 Al Carlson
# (28, 24)
# 661
# carlsdo01 Don Carlson
# (210, 23)
# 662
# carnebo01 Bob Carney
# (0, 23)
# 663
# carnero01 Rodney Carney
# (373, 30)
# 664
# carpebo01 Bob Carpenter
# (120, 23)
# 665
# carran01 Antoine Carr
# (1140, 30)
# 666
# carrau01 Austin Carr
# (700, 29)
# 667
# carrch01 Chris Carr
# (346, 30)
# 668
# carrco01 Cory Carr
# (45, 29)
# 669
# df shape (233753, 31)
# carrke01 Kenny Carr
# (709, 30)
# 670
# carrml01 M.L. Carr
# (771, 30)
# 671
# carrida01 Darel Carrier
# (397, 28)
# 672
# carribo01 Bob Carrington
# (82, 28)
# 673
# carrode01 DeMarre Carroll
# (926, 30)
# 674
# carrojo01 Joe Barry Carroll
# (724, 30)
# 675
# carroma01 Matt Carroll
# (629, 30)
# 676
# carruji01 Jimmy Carruth
# (8, 29)
# 677
# cartean01 Anthony Carter
# (877, 30)
# 678
# cartebu01 Butch Carter
# (361, 29)
# 679
# df shape (239237, 31)
# cartefr01 Fred Carter
# (637, 25)
# 680
# cartege01 George Carter
# (505, 28)
# 681
# carteho01 Howard Carter
# (71, 30)
# 682
# carteja01 Jake Carter
# (24, 23)
# 683
# carteje01 Jevon Carter
# (147, 29)
# 684
# cartema01 Maurice Carter
# (21, 30)
# 685
# cartere01 Reggie Carter
# (136, 29)
# 686
# cartero01 Ron Carter
# (61, 29)
# 687
# cartevi01 Vince Carter
# (1813, 30)
# 688
# cartewe01 Wendell Carter
# (147, 29)
# 689
# df shape (242799, 31)
# cartemi01 Michael Carter-Williams
# (542, 31)
# 690
# cartwbi01 Bill Cartwright
# (1087, 30)
# 691
# cartyja01 Jay Carty
# (29, 23)
# 692
# carusal01 Alex Caruso
# (226, 29)
# 693
# cashco01 Cornelius Cash
# (6, 24)
# 694
# cashsa01 Sam Cash
# (6, 27)
# 695
# cassesa01 Sam Cassell
# (1265, 30)
# 696
# casspom01 Omri Casspi
# (765, 29)
# 697
# catchha01 Harvey Catchings
# (777, 30)
# 698
# catlete01 Terry Catledge
# (534, 30)
# 699
# df shape (248036, 31)
# catlesi01 Sid Catlett
# (9, 22)
# 700
# catoke01 Kelvin Cato
# (754, 30)
# 701
# cattabo01 Bobby Cattage
# (78, 29)
# 702
# caulewi01 Willie Cauley-Stein
# (398, 29)
# 703
# caupatr01 Troy Caupain
# (82, 29)
# 704
# causwdu01 Duane Causwell
# (724, 30)
# 705
# cavanty01 Tyler Cavanaugh
# (155, 29)
# 706
# cavenro01 Ron Cavenall
# (58, 29)
# 707
# cebalce01 Cedric Ceballos
# (755, 30)
# 708
# celesjo01 John Celestand
# (23, 29)
# 709
# df shape (251072, 31)
# cervial01 Al Cervi*
# (227, 23)
# 710
# chalmli01 Lionel Chalmers
# (78, 29)
# 711
# chalmma01 Mario Chalmers
# (802, 30)
# 712
# chambbi01 Bill Chamberlain
# (77, 27)
# 713
# chambwi01 Wilt Chamberlain*
# (1205, 23)
# 714
# chambje01 Jerry Chambers
# (334, 28)
# 715
# chambto01 Tom Chambers
# (1227, 30)
# 716
# champmi01 Mike Champion
# (2, 29)
# 717
# chandty01 Tyson Chandler
# (1561, 30)
# 718
# chandwi01 Wilson Chandler
# (999, 31)
# 719
# df shape (257584, 31)
# chanedo01 Don Chaney
# (860, 29)
# 720
# chanejo01 John Chaney
# (15, 22)
# 721
# chapmre01 Rex Chapman
# (717, 30)
# 722
# chapmwa01 Wayne Chapman

# %%
print(game_logs.shape)

# %%
game_logs.tail()

# %%
|
# Out:
#   File "<ipython-input-16-4b37ef281455>", line 1
#     |
#     ^
# SyntaxError: invalid syntax

# %%
playoff_game_logs = None

row = df.iloc[0]

player_idx = row['index']
letter = player_idx[0]
player_name = row['Player']
print(letter,player_idx,player_name)

from_yr, to_yr = row[["From","To"]].values

#playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs/"
playoff_url = f"https://www.basketball-reference.com/players/{letter}/{player_idx}/gamelog-playoffs-advanced/"
webpage = urlopen(playoff_url)
html = BeautifulSoup(webpage)
tables = html.findAll('table')

if len(tables) > 0:
    table = str(html.findAll('table')[-1])
    playoff_game_logs = pd.read_html(table)[0]
    playoff_game_logs["PLAYOFF"] = 'Y'

# %%
playoff_game_logs
